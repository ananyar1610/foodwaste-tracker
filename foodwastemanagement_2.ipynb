# %% [markdown]
# 08/06/2025- Food Waste Management

# %% [markdown]
# Problem Statement
#
# Food wastage is a significant issue, with many households and restaurants discarding surplus food while numerous people struggle with food insecurity. This project aims to develop a Local Food Wastage Management System, where:
#
# 1.Restaurants and individuals can list surplus food.
#
# 2.NGOs or individuals in need can claim the food.
#
# 3.SQL stores available food details and locations.
#
# 4.A Streamlit app enables interaction, filtering, CRUD operation and visualization.
#
#
# Business Use Cases
#
# 1.Connecting surplus food providers to those in need through a structured platform.
#
# 2.Reducing food waste by redistributing excess food efficiently.
#
# 3.Enhancing accessibility via geolocation features to locate food easily.
#
# 4.Data analysis on food wastage trends for better decision-making.

# %% [markdown]
# Step 1 : Download data into pandas

# %% [markdown]
#                 i. For food providers

# %%
import pandas as pd
df_providers=pd.read_csv(r"D:\GUVI2\Data\providers_data.csv")

# %% [markdown]
#                  a. Cleaning the data

# %%
df_providers.dropna(axis=1, how="all", inplace=True)
#Not including unique rovider id here
df_providers['Name'].fillna('Unknown', inplace=True)
df_providers['Type'].fillna('Unknown',inplace=True)
df_providers['Address'].fillna('Unknown',inplace=True)
df_providers['City'].fillna('Unknown',inplace=True)
df_providers['Contact'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14140\1279989716.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_providers['Name'].fillna('Unknown', inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14140\1279989716.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_providers['Type'].fillna('Unknown',inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14140\1279989716.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_providers['Address'].fillna('Unknown',inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14140\1279989716.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_providers['City'].fillna('Unknown',inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14140\1279989716.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_providers['Contact'].fillna('Unknown',inplace=True)

# %% [markdown]
#                 b. Create a Table

# %%
import mysql.connector
connection=mysql.connector.connect(
    host="localhost",
    user="root",
    password="Sadguro161092",
    database="DSB42"

)
cursor=connection.cursor()

# %%
query="""
CREATE TABLE IF NOT EXISTS providers(
    Provider_ID INT,
    Name VARCHAR(100),
    Type VARCHAR(100),
    Address VARCHAR(100),
    City VARCHAR(100),
    Contact VARCHAR(50)

);
"""
cursor.execute(query)
connection.commit()

# %%
columns_needed=[
    'Provider_ID','Name','Type','Address','City','Contact'
]
dfproviders_selected=df_providers[columns_needed]
rows_to_tuples=[tuple(x) for x in dfproviders_selected.to_numpy()]

# %%
insert_data="""
 INSERT INTO providers(
Provider_ID,Name,Type,Address,City,Contact)
 VALUES(%s, %s, %s,%s,%s,%s)
 """

cursor.executemany(insert_data, rows_to_tuples)

# %% [markdown]
#                 ii.For Reciver's dataset

# %%
df_receivers=pd.read_csv(r'D:\GUVI2\Data\receivers_data.csv')

# %% [markdown]
#                 a.Clean the data

# %%
df_receivers.dropna(axis=1, how='all', inplace=True)
#Not including unique receiver id
df_receivers['Name'].fillna('Unknown', inplace=True)
df_receivers['Type'].fillna('Unknown', inplace=True)
df_receivers['City'].fillna('Unknown', inplace=True)
df_receivers['Contact'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14140\911705583.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_receivers['Name'].fillna('Unknown', inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14140\911705583.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_receivers['Type'].fillna('Unknown', inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14140\911705583.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_receivers['City'].fillna('Unknown', inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14140\911705583.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_receivers['Contact'].fillna('Unknown',inplace=True)

# %% [markdown]
#                 b.Create a table

# %%
query="""
CREATE TABLE IF NOT EXISTS receivers(
    Receiver_ID INT,
    Name VARCHAR(100),
    Type VARCHAR(100),
    City VARCHAR(100),
    Contact VARCHAR(50)

);
"""
cursor.execute(query)
connection.commit()

# %%
columns_needed=[
    'Receiver_ID','Name','Type','City','Contact'
]
dfreceivers_selected=df_receivers[columns_needed]
rows_to_tuples=[tuple(x) for x in dfreceivers_selected.to_numpy()]

# %%
insert_data="""
 INSERT INTO receivers(
Receiver_ID,Name,Type,City,Contact)
 VALUES(%s, %s, %s,%s,%s)
 """

cursor.executemany(insert_data, rows_to_tuples)

# %% [markdown]
#         iii. For Food Listings Dataset

# %%
df_foodlistings=pd.read_csv(r"D:\GUVI2\Data\food_listings_data.csv")

# %% [markdown]
#                 a.Clean data

# %%
# Drop columns with all NaN values (excluding 'Food_ID')
df_foodlistings.dropna(axis=1, how='all', inplace=True)

# Fill NaN in 'Food_Name' with 'Unknown'
df_foodlistings['Food_Name'].fillna('Unknown', inplace=True)

# Fill NaN in 'Quantity' with the mean of the column (only if it's numeric)
df_foodlistings['Quantity'] = df_foodlistings['Quantity'].fillna(df_foodlistings['Quantity'].mean())

# Drop rows where 'Expiry_Date' or 'Provider_ID' are NaN
df_foodlistings.dropna(subset=['Expiry_Date', 'Provider_ID'], inplace=True)

# Fill NaN values for categorical columns in one go
df_foodlistings.fillna({
    'Provider_Type': 'Unknown',
    'Location': 'Unknown',
    'Food_Type': 'Unknown',
    'Meal_Type': 'Unknown'
}, inplace=True)

# Alternatively, you can use a more general approach if you'd like to fill any NaN
# values in object (string) columns with a default value, and numeric columns with the mean.
df_foodlistings = df_foodlistings.apply(lambda x: x.fillna(x.mean()) if x.dtype in ['float64', 'int64'] else x.fillna('Unknown'))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14140\3907010888.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_foodlistings['Food_Name'].fillna('Unknown', inplace=True)

# %%
query="""
CREATE TABLE IF NOT EXISTS foodlistings (
    Food_ID INT,                   -- Unique identifier for each food item
    Food_Name VARCHAR(100),        -- Name of the food item
    Quantity INT,                  -- Quantity available for distribution
    Expiry_Date DATE,              -- Expiry date of the food item
    Provider_ID INT,               -- Reference to the provider offering the food
    Provider_Type VARCHAR(100),    -- Type of provider offering the food
    Location VARCHAR(100),         -- City where the food is available
    Food_Type VARCHAR(100),        -- Category of food (e.g., Vegetarian, Non-Vegetarian, Vegan)
    Meal_Type VARCHAR(100)         -- Type of meal (e.g., Breakfast, Lunch, Dinner, Snacks)


);
"""
cursor.execute(query)
connection.commit()

# %%
columns_needed=[
    'Food_ID','Food_Name','Quantity','Expiry_Date','Provider_ID','Provider_Type','Location','Food_Type','Meal_Type'
]
df_foodlistings_selected=df_foodlistings[columns_needed]
rows_to_tuples=[tuple(x) for x in df_foodlistings_selected.to_numpy()]

# %%
insert_data = """
INSERT INTO foodlistings (
    Food_ID, Food_Name, Quantity, Expiry_Date, Provider_ID, 
    Provider_Type, Location, Food_Type, Meal_Type
) 
VALUES (%s, %s, %s, STR_TO_DATE(%s, '%c/%d/%Y'), %s, %s, %s, %s, %s)
"""


cursor.executemany(insert_data, rows_to_tuples)

# %% [markdown]
#         iv. For Claims Dataset

# %%
df_claims=pd.read_csv(r'D:\GUVI2\Data\claims_data.csv')

# %% [markdown]
#                 a. Clean Data

# %%
df_claims.head()
# Out:
#    Claim_ID  Food_ID  Receiver_ID     Status        Timestamp
# 0         1      164          908    Pending    3/5/2025 5:26
# 1         2      353          391  Cancelled  3/11/2025 10:24
# 2         3      626          492  Completed   3/21/2025 0:59
# 3         4       61          933  Cancelled    3/4/2025 9:08
# 4         5      345          229    Pending  3/14/2025 15:17

# %%
df_claims.dropna(subset=['Claim_ID'], inplace=True)
df_claims.dropna(subset=['Food_ID'],inplace=True)
df_claims.dropna(subset=['Receiver_ID'],inplace=True)
df_claims['Status'].fillna('Unknown', inplace=True)
df_claims['Timestamp'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14140\3305683245.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_claims['Status'].fillna('Unknown', inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14140\3305683245.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_claims['Timestamp'].fillna('Unknown', inplace=True)

# %%
query="""
CREATE TABLE IF NOT EXISTS claims (
    Claim_ID INT,
    Food_ID INT,
    Receiver_ID INT,
    Status VARCHAR(100),
    Timestamp VARCHAR(100)

);
"""
cursor.execute(query)
connection.commit()

# %%
columns_needed=[
    'Claim_ID','Food_ID','Receiver_ID','Status','Timestamp'
]
df_claims_selected=df_claims[columns_needed]
rows_to_tuples=[tuple(x) for x in df_claims_selected.to_numpy()]

# %%
insert_data = """
INSERT INTO claims (
    Claim_ID, Food_ID, Receiver_ID, Status, Timestamp
) 
VALUES (%s, %s, %s, %s, %s)
"""


cursor.executemany(insert_data, rows_to_tuples)

# %% [markdown]
# SOME BASIC EDA OPERATIONS:

# %%
print("\nDuplicate Rows in Providers Dataset:",df_providers.duplicated().sum())
print("\nDuplicate Rows in Receivers Dataset:",df_receivers.duplicated().sum())
print("\nDuplicate Rows in Food Listings Dataset:",df_foodlistings.duplicated().sum())
print("\nDuplicate Rows in Claims Dataset:", df_claims.duplicated().sum())
# Out:
# Duplicate Rows in Providers Dataset: 0
#
# Duplicate Rows in Receivers Dataset: 0
#
# Duplicate Rows in Food Listings Dataset: 0
#
# Duplicate Rows in Claims Dataset: 0

# %%
print("Shape:",df_providers.shape)
print("Data Types:\n",df_providers.dtypes)
print("Missing values: \n",df_providers.isnull().sum())
print("Sample Data:\n", df_providers.head(),"\n")
# Out:
# Shape: (1000, 6)
# Data Types:
#  Provider_ID     int64
# Name           object
# Type           object
# Address        object
# City           object
# Contact        object
# dtype: object
# Missing values:
#  Provider_ID    0
# Name           0
# Type           0
# Address        0
# City           0
# Contact        0
# dtype: int64
# Sample Data:
#     Provider_ID                         Name           Type  \
# 0            1             Gonzales-Cochran    Supermarket
# 1            2  Nielsen, Johnson and Fuller  Grocery Store
# 2            3                 Miller-Black    Supermarket
# 3            4   Clark, Prince and Williams  Grocery Store
# 4            5               Coleman-Farley  Grocery Store
#
#                                              Address            City  \
# 0  74347 Christopher Extensions\nAndreamouth, OK ...     New Jessica
# 1           91228 Hanson Stream\nWelchtown, OR 27136     East Sheena
# 2  561 Martinez Point Suite 507\nGuzmanchester, W...  Lake Jesusview
# 3     467 Bell Trail Suite 409\nPort Jesus, IA 61188     Mendezmouth
# 4  078 Matthew Creek Apt. 319\nSaraborough, MA 53978   Valentineside
#
#                 Contact
# 0       +1-600-220-0480
# 1  +1-925-283-8901x6297
# 2      001-517-295-2206
# 3      556.944.8935x401
# 4          193.714.6577

# %%
print("Shape:",df_receivers.shape)
print("Data Types:\n",df_receivers.dtypes)
print("Missing values: \n",df_receivers.isnull().sum())
print("Sample Data:\n", df_receivers.head(),"\n")
# Out:
# Shape: (1000, 5)
# Data Types:
#  Receiver_ID     int64
# Name           object
# Type           object
# City           object
# Contact        object
# dtype: object
# Missing values:
#  Receiver_ID    0
# Name           0
# Type           0
# City           0
# Contact        0
# dtype: int64
# Sample Data:
#     Receiver_ID          Name        Type               City           Contact
# 0            1  Donald Gomez     Shelter     Port Carlburgh     (955)922-5295
# 1            2  Laurie Ramos  Individual         Lewisburgh      761.042.1570
# 2            3  Ashley Mckee         NGO  South Randalltown  691-023-0094x856
# 3            4    Erika Rose         NGO   South Shaneville        8296491111
# 4            5   John Romero  Individual          Bakerport      067.491.0154

# %%
print("Shape:",df_foodlistings.shape)
print("Data Types:\n",df_foodlistings.dtypes)
print("Missing values: \n",df_foodlistings.isnull().sum())
print("Sample Data:\n", df_foodlistings.head(),"\n")
# Out:
# Shape: (1000, 9)
# Data Types:
#  Food_ID           int64
# Food_Name        object
# Quantity          int64
# Expiry_Date      object
# Provider_ID       int64
# Provider_Type    object
# Location         object
# Food_Type        object
# Meal_Type        object
# dtype: object
# Missing values:
#  Food_ID          0
# Food_Name        0
# Quantity         0
# Expiry_Date      0
# Provider_ID      0
# Provider_Type    0
# Location         0
# Food_Type        0
# Meal_Type        0
# dtype: int64
# Sample Data:
#     Food_ID Food_Name  Quantity Expiry_Date  Provider_ID     Provider_Type  \
# 0        1     Bread        43   3/17/2025          110     Grocery Store
# 1        2      Soup        22   3/24/2025          791     Grocery Store
# 2        3    Fruits        46   3/28/2025          478  Catering Service
# 3        4    Fruits        15   3/16/2025          930        Restaurant
# 4        5      Soup        14   3/19/2025          279        Restaurant
#
#            Location       Food_Type  Meal_Type
# 0  South Kellyville  Non-Vegetarian  Breakfast
# 1        West James  Non-Vegetarian     Dinner
# 2       Lake Regina           Vegan  Breakfast
# 3         Kellytown           Vegan      Lunch
# 4        Garciaport           Vegan     Dinner

# %%
print("Shape:",df_claims.shape)
print("Data Types:\n",df_claims.dtypes)
print("Missing values: \n",df_claims.isnull().sum())
print("Sample Data:\n", df_claims.head(),"\n")
# Out:
# Shape: (1000, 5)
# Data Types:
#  Claim_ID        int64
# Food_ID         int64
# Receiver_ID     int64
# Status         object
# Timestamp      object
# dtype: object
# Missing values:
#  Claim_ID       0
# Food_ID        0
# Receiver_ID    0
# Status         0
# Timestamp      0
# dtype: int64
# Sample Data:
#     Claim_ID  Food_ID  Receiver_ID     Status        Timestamp
# 0         1      164          908    Pending    3/5/2025 5:26
# 1         2      353          391  Cancelled  3/11/2025 10:24
# 2         3      626          492  Completed   3/21/2025 0:59
# 3         4       61          933  Cancelled    3/4/2025 9:08
# 4         5      345          229    Pending  3/14/2025 15:17

# %% [markdown]
# SQL QUERIES

# %% [markdown]
#         A. FOOD PROVIDERS AND RECEIVERS

# %% [markdown]
#              1.How many food providers and receivers are there in each city?

# %%
query="""
SELECT
    p.City,
    COUNT(DISTINCT p.Provider_ID) AS Num_Providers,
    COUNT(DISTINCT r.Receiver_ID) AS Num_Receivers
FROM providers p
LEFT JOIN receivers r ON p.City=r.City
GROUP BY p.City


"""

cursor.execute(query)
results=cursor.fetchall()
for City, Num_Providers, Num_Receivers in results:
    print(f"{City}: {Num_Providers} Providers  |  {Num_Receivers} Receivers")
# Out:
# Adambury: 1 Providers  |  0 Receivers
# Adamsview: 1 Providers  |  0 Receivers
# Adamsville: 1 Providers  |  0 Receivers
# Aguirreville: 1 Providers  |  0 Receivers
# Alexanderchester: 1 Providers  |  0 Receivers
# Alexanderstad: 1 Providers  |  0 Receivers
# Allenborough: 1 Providers  |  1 Receivers
# Allenton: 1 Providers  |  0 Receivers
# Amandaborough: 1 Providers  |  0 Receivers
# Amandashire: 1 Providers  |  0 Receivers
# Amberton: 1 Providers  |  0 Receivers
# Ambertown: 1 Providers  |  0 Receivers
# Amyport: 1 Providers  |  0 Receivers
# Andersonmouth: 1 Providers  |  0 Receivers
# Andersonville: 1 Providers  |  0 Receivers
# Andreaborough: 1 Providers  |  0 Receivers
# Andrewsmouth: 1 Providers  |  0 Receivers
# Andrewstad: 1 Providers  |  0 Receivers
# Anitashire: 1 Providers  |  0 Receivers
# Annahaven: 1 Providers  |  0 Receivers
# Annetteburgh: 1 Providers  |  0 Receivers
# Anneville: 1 Providers  |  0 Receivers
# Anthonyborough: 1 Providers  |  0 Receivers
# Anthonychester: 1 Providers  |  0 Receivers
# Anthonyfort: 1 Providers  |  0 Receivers
# Anthonyhaven: 1 Providers  |  0 Receivers
# Anthonyshire: 1 Providers  |  0 Receivers
# Anthonyton: 1 Providers  |  0 Receivers
# Aprilberg: 1 Providers  |  0 Receivers
# Arnoldmouth: 1 Providers  |  0 Receivers
# Ashleyhaven: 1 Providers  |  0 Receivers
# Ashleyton: 1 Providers  |  0 Receivers
# Bairdfort: 1 Providers  |  0 Receivers
# Baldwinshire: 1 Providers  |  0 Receivers
# Barkerborough: 1 Providers  |  0 Receivers
# Barryside: 1 Providers  |  0 Receivers
# Bartonborough: 1 Providers  |  0 Receivers
# Basstown: 1 Providers  |  0 Receivers
# Batesstad: 1 Providers  |  0 Receivers
# Beasleyhaven: 1 Providers  |  0 Receivers
# Belindaville: 1 Providers  |  0 Receivers
# Bellport: 1 Providers  |  0 Receivers
# Benjaminstad: 1 Providers  |  0 Receivers
# Bentleyburgh: 1 Providers  |  0 Receivers
# Bentonfurt: 1 Providers  |  0 Receivers
# Blaketown: 1 Providers  |  0 Receivers
# Bonillahaven: 1 Providers  |  0 Receivers
# Boylechester: 1 Providers  |  0 Receivers
# Bradleyborough: 1 Providers  |  0 Receivers
# Bradleyport: 2 Providers  |  0 Receivers
# Bradleyview: 1 Providers  |  0 Receivers
# Brandyberg: 1 Providers  |  0 Receivers
# Brendantown: 1 Providers  |  0 Receivers
# Brennanstad: 1 Providers  |  0 Receivers
# Brewerfort: 1 Providers  |  0 Receivers
# Brianside: 1 Providers  |  0 Receivers
# Bridgetside: 1 Providers  |  0 Receivers
# Brittanyland: 1 Providers  |  0 Receivers
# Brittanyport: 1 Providers  |  0 Receivers
# Brittanyside: 1 Providers  |  0 Receivers
# Brittanyville: 1 Providers  |  0 Receivers
# Brookeland: 1 Providers  |  0 Receivers
# Brownberg: 1 Providers  |  0 Receivers
# Brownchester: 1 Providers  |  0 Receivers
# Browninghaven: 1 Providers  |  0 Receivers
# Brownshire: 1 Providers  |  0 Receivers
# Brownton: 1 Providers  |  0 Receivers
# Browntown: 1 Providers  |  0 Receivers
# Bryantton: 1 Providers  |  0 Receivers
# Butlerview: 1 Providers  |  0 Receivers
# Cabreraberg: 1 Providers  |  0 Receivers
# Callahanside: 1 Providers  |  0 Receivers
# Cameronside: 1 Providers  |  0 Receivers
# Campbellbury: 1 Providers  |  0 Receivers
# Campbellchester: 1 Providers  |  1 Receivers
# Cannonside: 1 Providers  |  0 Receivers
# Carlborough: 1 Providers  |  0 Receivers
# Carlbury: 1 Providers  |  0 Receivers
# Carolchester: 1 Providers  |  0 Receivers
# Carrport: 1 Providers  |  0 Receivers
# Cassandraville: 1 Providers  |  0 Receivers
# Castilloport: 1 Providers  |  0 Receivers
# Chadview: 1 Providers  |  0 Receivers
# Chambersfort: 1 Providers  |  0 Receivers
# Charlesland: 1 Providers  |  0 Receivers
# Charlesmouth: 1 Providers  |  0 Receivers
# Charlesview: 1 Providers  |  0 Receivers
# Chelseaside: 1 Providers  |  0 Receivers
# Chelseyfort: 1 Providers  |  0 Receivers
# Christianfurt: 1 Providers  |  0 Receivers
# Christinaland: 1 Providers  |  1 Receivers
# Christinamouth: 1 Providers  |  0 Receivers
# Christinetown: 1 Providers  |  0 Receivers
# Christopherchester: 1 Providers  |  2 Receivers
# Christopherside: 1 Providers  |  0 Receivers
# Christopherstad: 1 Providers  |  0 Receivers
# Christopherton: 1 Providers  |  0 Receivers
# Cindyshire: 1 Providers  |  0 Receivers
# Cisnerostown: 1 Providers  |  0 Receivers
# Clarkberg: 1 Providers  |  0 Receivers
# Codyview: 1 Providers  |  0 Receivers
# Coleburgh: 1 Providers  |  0 Receivers
# Colemanton: 1 Providers  |  0 Receivers
# Collinsmouth: 1 Providers  |  0 Receivers
# Collinston: 1 Providers  |  0 Receivers
# Connieside: 1 Providers  |  0 Receivers
# Contrerasberg: 1 Providers  |  0 Receivers
# Coopermouth: 1 Providers  |  0 Receivers
# Copelandchester: 1 Providers  |  0 Receivers
# Cordovaborough: 1 Providers  |  0 Receivers
# Courtneychester: 1 Providers  |  0 Receivers
# Crystalborough: 1 Providers  |  0 Receivers
# Cummingstown: 1 Providers  |  0 Receivers
# Cunninghambury: 1 Providers  |  0 Receivers
# Danachester: 1 Providers  |  0 Receivers
# Danaville: 1 Providers  |  0 Receivers
# Dannybury: 1 Providers  |  0 Receivers
# Darrellfurt: 1 Providers  |  0 Receivers
# Darrylchester: 1 Providers  |  0 Receivers
# Davidborough: 1 Providers  |  0 Receivers
# Davidchester: 1 Providers  |  0 Receivers
# Davidland: 1 Providers  |  1 Receivers
# Davidport: 1 Providers  |  1 Receivers
# Davidville: 2 Providers  |  0 Receivers
# Davisshire: 1 Providers  |  0 Receivers
# Davisview: 1 Providers  |  0 Receivers
# Deanport: 1 Providers  |  0 Receivers
# Deborahfurt: 1 Providers  |  0 Receivers
# Deborahland: 1 Providers  |  0 Receivers
# Deckermouth: 1 Providers  |  0 Receivers
# Derekland: 1 Providers  |  0 Receivers
# Derekport: 1 Providers  |  0 Receivers
# Derekshire: 1 Providers  |  0 Receivers
# Devinmouth: 1 Providers  |  0 Receivers
# Devinton: 1 Providers  |  0 Receivers
# Donnaborough: 1 Providers  |  0 Receivers
# Drakeville: 1 Providers  |  0 Receivers
# Durhamchester: 1 Providers  |  0 Receivers
# East Aaron: 1 Providers  |  0 Receivers
# East Alexisberg: 1 Providers  |  0 Receivers
# East Amyfurt: 1 Providers  |  0 Receivers
# East Amymouth: 1 Providers  |  0 Receivers
# East Andrea: 1 Providers  |  0 Receivers
# East Andrewland: 1 Providers  |  0 Receivers
# East Angela: 1 Providers  |  0 Receivers
# East Angelafort: 1 Providers  |  0 Receivers
# East Annshire: 1 Providers  |  0 Receivers
# East Anthony: 2 Providers  |  0 Receivers
# East Ashleyshire: 1 Providers  |  1 Receivers
# East Austin: 1 Providers  |  0 Receivers
# East Benjaminland: 1 Providers  |  0 Receivers
# East Bernard: 1 Providers  |  0 Receivers
# East Brittanyland: 1 Providers  |  0 Receivers
# East Candace: 1 Providers  |  0 Receivers
# East Caseyfort: 1 Providers  |  0 Receivers
# East Christophertown: 1 Providers  |  0 Receivers
# East Courtneymouth: 1 Providers  |  0 Receivers
# East Craig: 1 Providers  |  0 Receivers
# East Cynthia: 1 Providers  |  0 Receivers
# East Darrell: 1 Providers  |  0 Receivers
# East Deborah: 1 Providers  |  0 Receivers
# East Deniseborough: 1 Providers  |  0 Receivers
# East Donnafort: 1 Providers  |  0 Receivers
# East Edwinburgh: 1 Providers  |  0 Receivers
# East Elizabeth: 1 Providers  |  0 Receivers
# East Elizabethberg: 1 Providers  |  0 Receivers
# East Emily: 1 Providers  |  1 Receivers
# East Emilyburgh: 1 Providers  |  0 Receivers
# East Garyton: 1 Providers  |  0 Receivers
# East Heather: 1 Providers  |  0 Receivers
# East Heatherport: 1 Providers  |  0 Receivers
# East Jacobchester: 1 Providers  |  0 Receivers
# East Janet: 1 Providers  |  0 Receivers
# East Jennifer: 2 Providers  |  0 Receivers
# East Jesse: 1 Providers  |  0 Receivers
# East John: 1 Providers  |  1 Receivers
# East Johnburgh: 1 Providers  |  0 Receivers
# East Joseph: 1 Providers  |  1 Receivers
# East Kevin: 1 Providers  |  1 Receivers
# East Kimberly: 1 Providers  |  0 Receivers
# East Laura: 1 Providers  |  0 Receivers
# East Laurashire: 1 Providers  |  0 Receivers
# East Lauren: 1 Providers  |  0 Receivers
# East Lindsayville: 1 Providers  |  0 Receivers
# East Lisa: 2 Providers  |  0 Receivers
# East Lori: 1 Providers  |  0 Receivers
# East Meganfort: 1 Providers  |  0 Receivers
# East Melissa: 2 Providers  |  0 Receivers
# East Michael: 1 Providers  |  2 Receivers
# East Michelle: 1 Providers  |  0 Receivers
# East Nicholasbury: 1 Providers  |  0 Receivers
# East Phillipton: 1 Providers  |  0 Receivers
# East Richardside: 1 Providers  |  0 Receivers
# East Robert: 1 Providers  |  1 Receivers
# East Roberthaven: 1 Providers  |  0 Receivers
# East Robertton: 1 Providers  |  0 Receivers
# East Rossside: 1 Providers  |  0 Receivers
# East Samantha: 1 Providers  |  0 Receivers
# East Sandra: 1 Providers  |  0 Receivers
# East Sandratown: 1 Providers  |  0 Receivers
# East Shanestad: 1 Providers  |  0 Receivers
# East Sheena: 1 Providers  |  0 Receivers
# East Sonyaport: 1 Providers  |  0 Receivers
# East Stephanie: 2 Providers  |  0 Receivers
# East Stephanieview: 1 Providers  |  0 Receivers
# East Tammy: 1 Providers  |  0 Receivers
# East Terrancemouth: 1 Providers  |  0 Receivers
# East Timothy: 1 Providers  |  0 Receivers
# East Williamburgh: 1 Providers  |  0 Receivers
# East Williamshire: 1 Providers  |  0 Receivers
# Edwardsbury: 1 Providers  |  0 Receivers
# Elliottberg: 1 Providers  |  0 Receivers
# Ericfort: 1 Providers  |  0 Receivers
# Erikatown: 1 Providers  |  0 Receivers
# Estradafort: 1 Providers  |  0 Receivers
# Evansmouth: 1 Providers  |  0 Receivers
# Fisherstad: 1 Providers  |  0 Receivers
# Flemingport: 1 Providers  |  0 Receivers
# Floresville: 1 Providers  |  0 Receivers
# Fowlerbury: 1 Providers  |  0 Receivers
# Francisshire: 1 Providers  |  0 Receivers
# Frederickside: 1 Providers  |  0 Receivers
# Frostberg: 1 Providers  |  0 Receivers
# Fullerborough: 1 Providers  |  0 Receivers
# Gaineschester: 1 Providers  |  0 Receivers
# Galvanfurt: 1 Providers  |  0 Receivers
# Garciaberg: 1 Providers  |  0 Receivers
# Garciamouth: 1 Providers  |  0 Receivers
# Garciaport: 1 Providers  |  0 Receivers
# Garciaside: 1 Providers  |  0 Receivers
# Garciatown: 1 Providers  |  0 Receivers
# Gardnerfort: 1 Providers  |  0 Receivers
# Garzaville: 1 Providers  |  0 Receivers
# Gibsonfort: 1 Providers  |  0 Receivers
# Ginaview: 1 Providers  |  1 Receivers
# Gomezfurt: 1 Providers  |  0 Receivers
# Gonzalesport: 1 Providers  |  0 Receivers
# Grahamside: 1 Providers  |  0 Receivers
# Gutierrezshire: 1 Providers  |  0 Receivers
# Hamiltontown: 1 Providers  |  0 Receivers
# Harrishaven: 1 Providers  |  0 Receivers
# Harrisonbury: 1 Providers  |  0 Receivers
# Hawkinsmouth: 1 Providers  |  0 Receivers
# Hayesville: 1 Providers  |  0 Receivers
# Heathborough: 1 Providers  |  0 Receivers
# Heathermouth: 1 Providers  |  0 Receivers
# Heatherside: 1 Providers  |  0 Receivers
# Heatherview: 1 Providers  |  0 Receivers
# Henrychester: 1 Providers  |  0 Receivers
# Herbertbury: 1 Providers  |  0 Receivers
# Hestermouth: 1 Providers  |  0 Receivers
# Hillburgh: 1 Providers  |  0 Receivers
# Hollyhaven: 1 Providers  |  0 Receivers
# Holtmouth: 1 Providers  |  0 Receivers
# Huberstad: 1 Providers  |  0 Receivers
# Huntermouth: 1 Providers  |  1 Receivers
# Jameschester: 1 Providers  |  0 Receivers
# Jamesfurt: 1 Providers  |  0 Receivers
# Jamesport: 2 Providers  |  0 Receivers
# Jamesview: 1 Providers  |  1 Receivers
# Jamesville: 1 Providers  |  0 Receivers
# Janetborough: 1 Providers  |  0 Receivers
# Jasmineberg: 1 Providers  |  0 Receivers
# Jasminechester: 1 Providers  |  0 Receivers
# Jasonland: 1 Providers  |  0 Receivers
# Jasonmouth: 1 Providers  |  0 Receivers
# Jasonstad: 1 Providers  |  0 Receivers
# Jefferyside: 1 Providers  |  0 Receivers
# Jeffreyburgh: 1 Providers  |  0 Receivers
# Jeffreybury: 1 Providers  |  0 Receivers
# Jeffreyport: 1 Providers  |  0 Receivers
# Jeffreyshire: 1 Providers  |  0 Receivers
# Jennifertown: 1 Providers  |  0 Receivers
# Jenniferview: 1 Providers  |  0 Receivers
# Jenniferville: 1 Providers  |  0 Receivers
# Jeremiahfort: 1 Providers  |  0 Receivers
# Jessestad: 1 Providers  |  0 Receivers
# Jessicaland: 1 Providers  |  1 Receivers
# Jimmyberg: 1 Providers  |  0 Receivers
# Jimmymouth: 1 Providers  |  0 Receivers
# Johnport: 1 Providers  |  0 Receivers
# Johnsonborough: 1 Providers  |  0 Receivers
# Johnsonside: 1 Providers  |  0 Receivers
# Johnstonhaven: 1 Providers  |  0 Receivers
# Johnton: 1 Providers  |  0 Receivers
# Jonathanhaven: 1 Providers  |  0 Receivers
# Jonathanmouth: 1 Providers  |  0 Receivers
# Jonathanstad: 2 Providers  |  0 Receivers
# Joneshaven: 1 Providers  |  0 Receivers
# Jonesport: 1 Providers  |  0 Receivers
# Jonestown: 1 Providers  |  0 Receivers
# Jordanberg: 1 Providers  |  0 Receivers
# Jordanborough: 1 Providers  |  0 Receivers
# Jordanhaven: 1 Providers  |  0 Receivers
# Josephburgh: 1 Providers  |  0 Receivers
# Joseville: 1 Providers  |  0 Receivers
# Joshuastad: 1 Providers  |  0 Receivers
# Judystad: 1 Providers  |  0 Receivers
# Justinhaven: 1 Providers  |  0 Receivers
# Kaitlynville: 1 Providers  |  0 Receivers
# Karentown: 1 Providers  |  0 Receivers
# Katherineborough: 1 Providers  |  0 Receivers
# Katherinefurt: 1 Providers  |  0 Receivers
# Kayleefort: 1 Providers  |  0 Receivers
# Keithburgh: 1 Providers  |  0 Receivers
# Kellyberg: 1 Providers  |  0 Receivers
# Kellytown: 1 Providers  |  0 Receivers
# Kennedychester: 1 Providers  |  0 Receivers
# Kentland: 1 Providers  |  0 Receivers
# Kevinfort: 1 Providers  |  0 Receivers
# Kimberlychester: 1 Providers  |  0 Receivers
# Kylehaven: 1 Providers  |  0 Receivers
# Lake Alexis: 1 Providers  |  0 Receivers
# Lake Alicia: 1 Providers  |  0 Receivers
# Lake Allen: 1 Providers  |  0 Receivers
# Lake Amymouth: 1 Providers  |  0 Receivers
# Lake Andrewmouth: 1 Providers  |  0 Receivers
# Lake Anthonyport: 1 Providers  |  0 Receivers
# Lake April: 1 Providers  |  0 Receivers
# Lake Benjamin: 2 Providers  |  0 Receivers
# Lake Bianca: 1 Providers  |  0 Receivers
# Lake Brendaland: 1 Providers  |  0 Receivers
# Lake Carlos: 1 Providers  |  0 Receivers
# Lake Cathy: 1 Providers  |  0 Receivers
# Lake Charleston: 1 Providers  |  0 Receivers
# Lake Cheryl: 1 Providers  |  0 Receivers
# Lake Chloeshire: 1 Providers  |  0 Receivers
# Lake Christinaborough: 1 Providers  |  0 Receivers
# Lake Christopherburgh: 1 Providers  |  0 Receivers
# Lake Christophermouth: 1 Providers  |  0 Receivers
# Lake Coryhaven: 1 Providers  |  0 Receivers
# Lake Deborah: 1 Providers  |  0 Receivers
# Lake Dennischester: 1 Providers  |  0 Receivers
# Lake Devon: 1 Providers  |  0 Receivers
# Lake Diane: 1 Providers  |  0 Receivers
# Lake Donaldchester: 1 Providers  |  0 Receivers
# Lake Donaldmouth: 1 Providers  |  0 Receivers
# Lake Donna: 1 Providers  |  0 Receivers
# Lake Ethanview: 1 Providers  |  0 Receivers
# Lake Gary: 1 Providers  |  0 Receivers
# Lake George: 1 Providers  |  0 Receivers
# Lake Heather: 1 Providers  |  0 Receivers
# Lake Jaclyn: 1 Providers  |  0 Receivers
# Lake James: 1 Providers  |  0 Receivers
# Lake Jamestown: 1 Providers  |  0 Receivers
# Lake Jasmin: 1 Providers  |  0 Receivers
# Lake Jason: 1 Providers  |  0 Receivers
# Lake Jefferyborough: 1 Providers  |  0 Receivers
# Lake Jeffreytown: 1 Providers  |  0 Receivers
# Lake Jessicamouth: 1 Providers  |  0 Receivers
# Lake Jesusview: 1 Providers  |  0 Receivers
# Lake Joelshire: 1 Providers  |  0 Receivers
# Lake Joseph: 1 Providers  |  0 Receivers
# Lake Josephton: 1 Providers  |  0 Receivers
# Lake Justin: 1 Providers  |  0 Receivers
# Lake Karenfurt: 1 Providers  |  0 Receivers
# Lake Kari: 1 Providers  |  0 Receivers
# Lake Katherinechester: 1 Providers  |  0 Receivers
# Lake Kelly: 1 Providers  |  0 Receivers
# Lake Kendramouth: 1 Providers  |  0 Receivers
# Lake Kristentown: 1 Providers  |  0 Receivers
# Lake Kyle: 2 Providers  |  0 Receivers
# Lake Larry: 1 Providers  |  0 Receivers
# Lake Latasha: 1 Providers  |  0 Receivers
# Lake Lauraton: 1 Providers  |  0 Receivers
# Lake Lauren: 1 Providers  |  0 Receivers
# Lake Lindsay: 1 Providers  |  0 Receivers
# Lake Lindsey: 1 Providers  |  0 Receivers
# Lake Lisa: 1 Providers  |  0 Receivers
# Lake Lorrainefort: 1 Providers  |  0 Receivers
# Lake Maria: 1 Providers  |  0 Receivers
# Lake Michael: 2 Providers  |  1 Receivers
# Lake Michaelchester: 1 Providers  |  0 Receivers
# Lake Michaelfurt: 1 Providers  |  0 Receivers
# Lake Michaelview: 1 Providers  |  0 Receivers
# Lake Mistyton: 1 Providers  |  0 Receivers
# Lake Monique: 1 Providers  |  0 Receivers
# Lake Nathan: 1 Providers  |  0 Receivers
# Lake Nicolebury: 1 Providers  |  0 Receivers
# Lake Rachael: 1 Providers  |  0 Receivers
# Lake Raymondton: 1 Providers  |  0 Receivers
# Lake Regina: 2 Providers  |  0 Receivers
# Lake Richardhaven: 1 Providers  |  0 Receivers
# Lake Ryanbury: 1 Providers  |  0 Receivers
# Lake Sarah: 1 Providers  |  0 Receivers
# Lake Shelby: 1 Providers  |  0 Receivers
# Lake Stephen: 1 Providers  |  0 Receivers
# Lake Tamara: 1 Providers  |  0 Receivers
# Lake Theresa: 1 Providers  |  0 Receivers
# Lake Traceyburgh: 1 Providers  |  0 Receivers
# Lake Travis: 1 Providers  |  0 Receivers
# Lake Vanessa: 1 Providers  |  0 Receivers
# Lake Vanessaland: 1 Providers  |  0 Receivers
# Lake Xavierburgh: 1 Providers  |  0 Receivers
# Lamberttown: 1 Providers  |  0 Receivers
# Latoyaberg: 1 Providers  |  0 Receivers
# Laurietown: 1 Providers  |  0 Receivers
# Leeburgh: 1 Providers  |  0 Receivers
# Leonardborough: 1 Providers  |  0 Receivers
# Leonfort: 1 Providers  |  0 Receivers
# Leslieville: 2 Providers  |  0 Receivers
# Lesterstad: 1 Providers  |  0 Receivers
# Leville: 1 Providers  |  0 Receivers
# Levytown: 1 Providers  |  0 Receivers
# Lewisberg: 1 Providers  |  0 Receivers
# Lewishaven: 1 Providers  |  0 Receivers
# Liberg: 1 Providers  |  0 Receivers
# Linchester: 1 Providers  |  0 Receivers
# Lindseybury: 1 Providers  |  0 Receivers
# Lindseyland: 1 Providers  |  0 Receivers
# Lisaborough: 1 Providers  |  1 Receivers
# Lisafort: 1 Providers  |  0 Receivers
# Lisamouth: 1 Providers  |  0 Receivers
# Longland: 1 Providers  |  0 Receivers
# Lopezmouth: 1 Providers  |  0 Receivers
# Lopezport: 1 Providers  |  0 Receivers
# Louismouth: 1 Providers  |  0 Receivers
# Lucasmouth: 1 Providers  |  0 Receivers
# Madelinechester: 1 Providers  |  0 Receivers
# Madisonfort: 1 Providers  |  0 Receivers
# Manningshire: 1 Providers  |  0 Receivers
# Manuelhaven: 1 Providers  |  0 Receivers
# Marcstad: 1 Providers  |  0 Receivers
# Marissaville: 1 Providers  |  0 Receivers
# Markberg: 1 Providers  |  0 Receivers
# Markborough: 1 Providers  |  0 Receivers
# Markport: 1 Providers  |  0 Receivers
# Marthaside: 1 Providers  |  0 Receivers
# Martinezfort: 1 Providers  |  0 Receivers
# Martinville: 1 Providers  |  0 Receivers
# Marymouth: 1 Providers  |  0 Receivers
# Matthewbury: 1 Providers  |  0 Receivers
# Maxwellburgh: 1 Providers  |  0 Receivers
# Maynardstad: 1 Providers  |  0 Receivers
# Maysside: 1 Providers  |  0 Receivers
# Mcclainfurt: 1 Providers  |  0 Receivers
# Mckinneymouth: 1 Providers  |  0 Receivers
# Medinatown: 1 Providers  |  0 Receivers
# Meganshire: 1 Providers  |  0 Receivers
# Meghanfurt: 1 Providers  |  0 Receivers
# Mendezmouth: 1 Providers  |  0 Receivers
# Mendozastad: 1 Providers  |  0 Receivers
# Meyersland: 1 Providers  |  0 Receivers
# Michaelport: 1 Providers  |  0 Receivers
# Michaelton: 1 Providers  |  1 Receivers
# Michaelview: 1 Providers  |  0 Receivers
# Michellechester: 1 Providers  |  0 Receivers
# Mikaylachester: 1 Providers  |  0 Receivers
# Millerstad: 1 Providers  |  0 Receivers
# Millerview: 1 Providers  |  0 Receivers
# Mitchellmouth: 1 Providers  |  0 Receivers
# Mooneybury: 1 Providers  |  0 Receivers
# Mooremouth: 1 Providers  |  0 Receivers
# Mooreview: 1 Providers  |  0 Receivers
# Moralesberg: 1 Providers  |  0 Receivers
# Moralesside: 1 Providers  |  0 Receivers
# Morganhaven: 1 Providers  |  0 Receivers
# Morganside: 1 Providers  |  0 Receivers
# Morriston: 1 Providers  |  0 Receivers
# Mortonfort: 1 Providers  |  0 Receivers
# Moseshaven: 1 Providers  |  0 Receivers
# Muellermouth: 1 Providers  |  0 Receivers
# Murphyberg: 1 Providers  |  0 Receivers
# Murrayborough: 1 Providers  |  0 Receivers
# Myerschester: 1 Providers  |  0 Receivers
# Nathanielbury: 1 Providers  |  0 Receivers
# New Aaronberg: 1 Providers  |  0 Receivers
# New Amanda: 2 Providers  |  0 Receivers
# New Baileyfort: 1 Providers  |  0 Receivers
# New Billy: 1 Providers  |  0 Receivers
# New Bobbytown: 1 Providers  |  0 Receivers
# New Calebberg: 1 Providers  |  0 Receivers
# New Carol: 3 Providers  |  0 Receivers
# New Connorfort: 1 Providers  |  0 Receivers
# New Crystal: 1 Providers  |  0 Receivers
# New Curtis: 1 Providers  |  0 Receivers
# New Daniel: 2 Providers  |  1 Receivers
# New David: 1 Providers  |  0 Receivers
# New Dawnborough: 1 Providers  |  0 Receivers
# New Denise: 1 Providers  |  0 Receivers
# New Douglas: 1 Providers  |  0 Receivers
# New Emily: 1 Providers  |  0 Receivers
# New Erica: 1 Providers  |  0 Receivers
# New Evanport: 1 Providers  |  0 Receivers
# New Frank: 1 Providers  |  0 Receivers
# New Ginaborough: 1 Providers  |  0 Receivers
# New Hannah: 1 Providers  |  0 Receivers
# New Heidi: 1 Providers  |  0 Receivers
# New Hollyfurt: 1 Providers  |  0 Receivers
# New Jacob: 1 Providers  |  0 Receivers
# New Jamesburgh: 1 Providers  |  0 Receivers
# New Jason: 1 Providers  |  1 Receivers
# New Jenniferbury: 1 Providers  |  0 Receivers
# New Jeremyberg: 1 Providers  |  0 Receivers
# New Jessica: 1 Providers  |  1 Receivers
# New Joel: 1 Providers  |  0 Receivers
# New John: 2 Providers  |  0 Receivers
# New Johnfurt: 1 Providers  |  0 Receivers
# New Josemouth: 1 Providers  |  0 Receivers
# New Joshuamouth: 1 Providers  |  0 Receivers
# New Kevintown: 1 Providers  |  0 Receivers
# New Larry: 2 Providers  |  0 Receivers
# New Leslieport: 1 Providers  |  0 Receivers
# New Lisa: 2 Providers  |  0 Receivers
# New Matthew: 1 Providers  |  0 Receivers
# New Michaelmouth: 1 Providers  |  0 Receivers
# New Michelle: 1 Providers  |  0 Receivers
# New Monicaside: 1 Providers  |  0 Receivers
# New Natasha: 1 Providers  |  0 Receivers
# New Ninashire: 1 Providers  |  0 Receivers
# New Rachel: 1 Providers  |  0 Receivers
# New Rhonda: 1 Providers  |  0 Receivers
# New Richard: 2 Providers  |  0 Receivers
# New Ricky: 1 Providers  |  0 Receivers
# New Robert: 1 Providers  |  1 Receivers
# New Robertland: 1 Providers  |  0 Receivers
# New Robertstad: 1 Providers  |  0 Receivers
# New Rodneyville: 1 Providers  |  0 Receivers
# New Ryanbury: 1 Providers  |  0 Receivers
# New Samuel: 1 Providers  |  0 Receivers
# New Steven: 1 Providers  |  1 Receivers
# New Tammyland: 1 Providers  |  0 Receivers
# New Thomasmouth: 1 Providers  |  0 Receivers
# New Tiffanystad: 1 Providers  |  0 Receivers
# New Travisshire: 1 Providers  |  0 Receivers
# New Wendymouth: 1 Providers  |  0 Receivers
# New William: 1 Providers  |  1 Receivers
# New Willieburgh: 1 Providers  |  0 Receivers
# New Zachary: 2 Providers  |  0 Receivers
# Nicolefort: 1 Providers  |  0 Receivers
# Nicoletown: 1 Providers  |  0 Receivers
# Nolanmouth: 1 Providers  |  0 Receivers
# North Aaron: 1 Providers  |  0 Receivers
# North Alison: 1 Providers  |  0 Receivers
# North Amanda: 1 Providers  |  1 Receivers
# North Amber: 1 Providers  |  0 Receivers
# North Ashley: 2 Providers  |  0 Receivers
# North Bethanyville: 1 Providers  |  0 Receivers
# North Biancaview: 1 Providers  |  0 Receivers
# North Brendaborough: 1 Providers  |  0 Receivers
# North Brentbury: 1 Providers  |  0 Receivers
# North Briannabury: 1 Providers  |  0 Receivers
# North Brooke: 1 Providers  |  0 Receivers
# North Caitlin: 1 Providers  |  0 Receivers
# North Carmen: 1 Providers  |  0 Receivers
# North Carolfurt: 1 Providers  |  0 Receivers
# North Catherine: 1 Providers  |  0 Receivers
# North Charlesside: 1 Providers  |  0 Receivers
# North Chase: 1 Providers  |  0 Receivers
# North Christina: 1 Providers  |  2 Receivers
# North Crystal: 1 Providers  |  0 Receivers
# North Destiny: 1 Providers  |  0 Receivers
# North Douglasfurt: 1 Providers  |  0 Receivers
# North Ebony: 1 Providers  |  0 Receivers
# North Edwinchester: 1 Providers  |  0 Receivers
# North Elizabeth: 1 Providers  |  0 Receivers
# North Gary: 1 Providers  |  0 Receivers
# North Garybury: 1 Providers  |  0 Receivers
# North Ianbury: 1 Providers  |  0 Receivers
# North James: 1 Providers  |  0 Receivers
# North Jamesberg: 1 Providers  |  0 Receivers
# North Jenniferport: 1 Providers  |  0 Receivers
# North Joseph: 1 Providers  |  0 Receivers
# North Julieburgh: 2 Providers  |  0 Receivers
# North Katelyn: 1 Providers  |  0 Receivers
# North Katelynland: 1 Providers  |  0 Receivers
# North Katherineshire: 1 Providers  |  0 Receivers
# North Keith: 1 Providers  |  0 Receivers
# North Kennethshire: 1 Providers  |  0 Receivers
# North Kennethview: 1 Providers  |  0 Receivers
# North Kevinhaven: 2 Providers  |  0 Receivers
# North Kylestad: 1 Providers  |  0 Receivers
# North Lauren: 1 Providers  |  0 Receivers
# North Lindseychester: 1 Providers  |  0 Receivers
# North Lisaland: 1 Providers  |  0 Receivers
# North Lisamouth: 1 Providers  |  0 Receivers
# North Mariahchester: 1 Providers  |  0 Receivers
# North Marthaton: 1 Providers  |  0 Receivers
# North Mary: 1 Providers  |  0 Receivers
# North Melanie: 1 Providers  |  0 Receivers
# North Michelle: 2 Providers  |  1 Receivers
# North Mike: 1 Providers  |  0 Receivers
# North Nathan: 1 Providers  |  0 Receivers
# North Nicholas: 1 Providers  |  0 Receivers
# North Nicoleport: 1 Providers  |  0 Receivers
# North Paulstad: 1 Providers  |  0 Receivers
# North Ravenfurt: 1 Providers  |  0 Receivers
# North Richard: 1 Providers  |  0 Receivers
# North Ronaldburgh: 1 Providers  |  0 Receivers
# North Ronaldmouth: 1 Providers  |  0 Receivers
# North Ryan: 1 Providers  |  0 Receivers
# North Sharonberg: 1 Providers  |  0 Receivers
# North Sharonburgh: 1 Providers  |  0 Receivers
# North Sherrimouth: 1 Providers  |  0 Receivers
# North Stephanieville: 1 Providers  |  0 Receivers
# North Steven: 1 Providers  |  0 Receivers
# North Stevenbury: 1 Providers  |  0 Receivers
# North Susan: 1 Providers  |  0 Receivers
# North Tom: 1 Providers  |  0 Receivers
# North Tracy: 1 Providers  |  0 Receivers
# North Valerie: 1 Providers  |  0 Receivers
# North Victoriastad: 1 Providers  |  0 Receivers
# North William: 1 Providers  |  0 Receivers
# Olsenstad: 1 Providers  |  0 Receivers
# Owenschester: 1 Providers  |  0 Receivers
# Owensstad: 1 Providers  |  0 Receivers
# Padillamouth: 1 Providers  |  0 Receivers
# Padillatown: 1 Providers  |  0 Receivers
# Pamelaberg: 1 Providers  |  0 Receivers
# Pamelaburgh: 1 Providers  |  0 Receivers
# Parksburgh: 1 Providers  |  0 Receivers
# Patrickfort: 1 Providers  |  1 Receivers
# Patrickmouth: 1 Providers  |  0 Receivers
# Paulmouth: 1 Providers  |  1 Receivers
# Pearsonchester: 1 Providers  |  0 Receivers
# Penabury: 1 Providers  |  0 Receivers
# Perezport: 1 Providers  |  1 Receivers
# Pereztown: 1 Providers  |  0 Receivers
# Perkinsbury: 1 Providers  |  0 Receivers
# Peterhaven: 1 Providers  |  1 Receivers
# Petersonburgh: 1 Providers  |  0 Receivers
# Petersonside: 1 Providers  |  0 Receivers
# Phillipsfort: 2 Providers  |  0 Receivers
# Phillipsmouth: 1 Providers  |  0 Receivers
# Port Aaron: 1 Providers  |  0 Receivers
# Port Allisonland: 1 Providers  |  0 Receivers
# Port Amandamouth: 1 Providers  |  0 Receivers
# Port Andre: 1 Providers  |  0 Receivers
# Port Andrea: 1 Providers  |  0 Receivers
# Port Anita: 1 Providers  |  0 Receivers
# Port Brett: 1 Providers  |  0 Receivers
# Port Bryce: 1 Providers  |  0 Receivers
# Port Carrie: 1 Providers  |  0 Receivers
# Port Christina: 1 Providers  |  0 Receivers
# Port Christopher: 1 Providers  |  0 Receivers
# Port Connie: 1 Providers  |  0 Receivers
# Port Corystad: 1 Providers  |  0 Receivers
# Port Daniel: 1 Providers  |  0 Receivers
# Port Daniellechester: 1 Providers  |  0 Receivers
# Port David: 1 Providers  |  1 Receivers
# Port Davidshire: 1 Providers  |  0 Receivers
# Port Dianaberg: 1 Providers  |  0 Receivers
# Port Donnamouth: 1 Providers  |  0 Receivers
# Port Donnaton: 1 Providers  |  0 Receivers
# Port Dustin: 1 Providers  |  1 Receivers
# Port Emily: 1 Providers  |  0 Receivers
# Port Emilyburgh: 1 Providers  |  0 Receivers
# Port Eric: 1 Providers  |  0 Receivers
# Port Erin: 1 Providers  |  0 Receivers
# Port Erinton: 1 Providers  |  0 Receivers
# Port Glendastad: 1 Providers  |  0 Receivers
# Port Gregton: 1 Providers  |  0 Receivers
# Port Hannah: 1 Providers  |  0 Receivers
# Port Hannahmouth: 1 Providers  |  0 Receivers
# Port Heidiland: 1 Providers  |  0 Receivers
# Port Jacob: 1 Providers  |  0 Receivers
# Port Jeffrey: 1 Providers  |  0 Receivers
# Port Jennifer: 1 Providers  |  0 Receivers
# Port Jerome: 1 Providers  |  0 Receivers
# Port Jillian: 1 Providers  |  0 Receivers
# Port John: 1 Providers  |  0 Receivers
# Port Julia: 1 Providers  |  0 Receivers
# Port Juliafort: 1 Providers  |  0 Receivers
# Port Karen: 1 Providers  |  0 Receivers
# Port Kathleen: 1 Providers  |  0 Receivers
# Port Kendraborough: 1 Providers  |  0 Receivers
# Port Kevinburgh: 1 Providers  |  0 Receivers
# Port Lance: 1 Providers  |  0 Receivers
# Port Lauraville: 1 Providers  |  0 Receivers
# Port Lauriechester: 1 Providers  |  0 Receivers
# Port Leahfurt: 1 Providers  |  0 Receivers
# Port Lesliebury: 1 Providers  |  0 Receivers
# Port Linda: 1 Providers  |  0 Receivers
# Port Lisamouth: 1 Providers  |  0 Receivers
# Port Loganberg: 1 Providers  |  0 Receivers
# Port Manuel: 1 Providers  |  0 Receivers
# Port Marcland: 1 Providers  |  0 Receivers
# Port Mariefort: 1 Providers  |  0 Receivers
# Port Marissachester: 1 Providers  |  0 Receivers
# Port Markview: 1 Providers  |  0 Receivers
# Port Matthew: 1 Providers  |  0 Receivers
# Port Melanie: 1 Providers  |  0 Receivers
# Port Melissa: 2 Providers  |  1 Receivers
# Port Michael: 1 Providers  |  0 Receivers
# Port Michaelshire: 1 Providers  |  0 Receivers
# Port Pamelaport: 1 Providers  |  0 Receivers
# Port Patrick: 2 Providers  |  0 Receivers
# Port Peter: 1 Providers  |  0 Receivers
# Port Raymondburgh: 1 Providers  |  0 Receivers
# Port Rebekah: 1 Providers  |  0 Receivers
# Port Richardshire: 1 Providers  |  0 Receivers
# Port Robert: 1 Providers  |  0 Receivers
# Port Robertport: 1 Providers  |  0 Receivers
# Port Robin: 1 Providers  |  0 Receivers
# Port Ronaldshire: 1 Providers  |  0 Receivers
# Port Rubenville: 1 Providers  |  0 Receivers
# Port Staceymouth: 1 Providers  |  0 Receivers
# Port Tanyaburgh: 1 Providers  |  0 Receivers
# Port Timothystad: 1 Providers  |  0 Receivers
# Port Troychester: 1 Providers  |  0 Receivers
# Port Victoria: 1 Providers  |  0 Receivers
# Priceland: 1 Providers  |  0 Receivers
# Ramosville: 1 Providers  |  0 Receivers
# Ramseyfort: 1 Providers  |  0 Receivers
# Randallchester: 1 Providers  |  0 Receivers
# Randallville: 1 Providers  |  0 Receivers
# Raybury: 1 Providers  |  0 Receivers
# Raymondview: 1 Providers  |  0 Receivers
# Rebeccaburgh: 1 Providers  |  0 Receivers
# Rebeccabury: 1 Providers  |  0 Receivers
# Reidland: 1 Providers  |  0 Receivers
# Reyesshire: 1 Providers  |  0 Receivers
# Reynoldsbury: 1 Providers  |  0 Receivers
# Riceshire: 1 Providers  |  0 Receivers
# Richardfort: 1 Providers  |  0 Receivers
# Richardmouth: 1 Providers  |  0 Receivers
# Richardsonhaven: 1 Providers  |  0 Receivers
# Richardton: 1 Providers  |  1 Receivers
# Richchester: 1 Providers  |  0 Receivers
# Richton: 1 Providers  |  0 Receivers
# Ritterburgh: 1 Providers  |  0 Receivers
# Roachhaven: 1 Providers  |  0 Receivers
# Robertland: 1 Providers  |  0 Receivers
# Robertschester: 1 Providers  |  0 Receivers
# Robertshire: 1 Providers  |  0 Receivers
# Robertsonfort: 1 Providers  |  0 Receivers
# Robertton: 1 Providers  |  2 Receivers
# Robinsonfort: 1 Providers  |  0 Receivers
# Rodneystad: 1 Providers  |  0 Receivers
# Rodriguezfurt: 1 Providers  |  0 Receivers
# Rodriguezview: 1 Providers  |  0 Receivers
# Rogersmouth: 1 Providers  |  0 Receivers
# Roystad: 1 Providers  |  0 Receivers
# Ruizmouth: 1 Providers  |  0 Receivers
# Russellfurt: 1 Providers  |  0 Receivers
# Salastown: 1 Providers  |  0 Receivers
# Salinasville: 1 Providers  |  0 Receivers
# Samanthabury: 1 Providers  |  0 Receivers
# Samueltown: 1 Providers  |  0 Receivers
# Samuelville: 1 Providers  |  0 Receivers
# Sandersshire: 1 Providers  |  0 Receivers
# Sandrastad: 1 Providers  |  0 Receivers
# Saraburgh: 1 Providers  |  0 Receivers
# Sarahland: 1 Providers  |  0 Receivers
# Sarahside: 1 Providers  |  1 Receivers
# Sarahview: 1 Providers  |  0 Receivers
# Scottchester: 1 Providers  |  0 Receivers
# Scotthaven: 1 Providers  |  0 Receivers
# Scottton: 1 Providers  |  0 Receivers
# Shannonside: 1 Providers  |  0 Receivers
# Sharonton: 1 Providers  |  0 Receivers
# Shawnborough: 1 Providers  |  0 Receivers
# Sheenashire: 1 Providers  |  0 Receivers
# Sheilaburgh: 1 Providers  |  0 Receivers
# Shirleyland: 1 Providers  |  0 Receivers
# Shortfurt: 1 Providers  |  0 Receivers
# Smithfort: 1 Providers  |  0 Receivers
# Smithmouth: 1 Providers  |  0 Receivers
# Smithstad: 1 Providers  |  1 Receivers
# Snyderton: 1 Providers  |  0 Receivers
# Solisburgh: 1 Providers  |  0 Receivers
# South Alicia: 1 Providers  |  0 Receivers
# South Allison: 1 Providers  |  0 Receivers
# South Allisonburgh: 1 Providers  |  0 Receivers
# South Andrew: 1 Providers  |  0 Receivers
# South Andrewport: 1 Providers  |  0 Receivers
# South Anne: 1 Providers  |  0 Receivers
# South Bradleyburgh: 1 Providers  |  0 Receivers
# South Brandiberg: 1 Providers  |  0 Receivers
# South Brenda: 1 Providers  |  0 Receivers
# South Bryan: 1 Providers  |  0 Receivers
# South Cassandra: 1 Providers  |  0 Receivers
# South Charles: 1 Providers  |  0 Receivers
# South Christopherborough: 3 Providers  |  0 Receivers
# South Crystalberg: 1 Providers  |  0 Receivers
# South Danielle: 1 Providers  |  0 Receivers
# South Davidside: 1 Providers  |  0 Receivers
# South Donald: 1 Providers  |  0 Receivers
# South Douglashaven: 1 Providers  |  0 Receivers
# South Edwardtown: 1 Providers  |  0 Receivers
# South Jacobport: 1 Providers  |  0 Receivers
# South Jasmineville: 1 Providers  |  0 Receivers
# South Jason: 1 Providers  |  1 Receivers
# South Jeffery: 1 Providers  |  0 Receivers
# South Jeffrey: 1 Providers  |  0 Receivers
# South Jeffreyburgh: 1 Providers  |  0 Receivers
# South Jerryside: 1 Providers  |  0 Receivers
# South Jessicachester: 1 Providers  |  0 Receivers
# South Jillshire: 1 Providers  |  0 Receivers
# South Johnshire: 1 Providers  |  0 Receivers
# South Joshua: 1 Providers  |  0 Receivers
# South Justinborough: 1 Providers  |  0 Receivers
# South Karen: 1 Providers  |  0 Receivers
# South Kathryn: 1 Providers  |  0 Receivers
# South Kayla: 1 Providers  |  0 Receivers
# South Kelly: 1 Providers  |  0 Receivers
# South Kellyberg: 1 Providers  |  0 Receivers
# South Kellyland: 1 Providers  |  0 Receivers
# South Kellyville: 1 Providers  |  0 Receivers
# South Kendra: 1 Providers  |  0 Receivers
# South Kevinhaven: 1 Providers  |  0 Receivers
# South Linda: 1 Providers  |  0 Receivers
# South Lisaberg: 1 Providers  |  0 Receivers
# South Lisabury: 1 Providers  |  0 Receivers
# South Louis: 1 Providers  |  0 Receivers
# South Marthahaven: 1 Providers  |  0 Receivers
# South Melanieshire: 1 Providers  |  0 Receivers
# South Michaelberg: 1 Providers  |  0 Receivers
# South Michaelhaven: 1 Providers  |  0 Receivers
# South Michellechester: 1 Providers  |  0 Receivers
# South Morganfurt: 1 Providers  |  0 Receivers
# South Nicholasville: 1 Providers  |  0 Receivers
# South Nicole: 1 Providers  |  0 Receivers
# South Randy: 1 Providers  |  0 Receivers
# South Richard: 1 Providers  |  1 Receivers
# South Richardhaven: 1 Providers  |  0 Receivers
# South Robert: 1 Providers  |  0 Receivers
# South Russelltown: 1 Providers  |  0 Receivers
# South Sarahville: 1 Providers  |  0 Receivers
# South Sarastad: 1 Providers  |  0 Receivers
# South Stefanietown: 1 Providers  |  0 Receivers
# South Tammy: 1 Providers  |  0 Receivers
# South Thomas: 2 Providers  |  0 Receivers
# South Thomasville: 1 Providers  |  0 Receivers
# South Tiffanyfort: 1 Providers  |  0 Receivers
# South Tina: 1 Providers  |  0 Receivers
# South Tylerstad: 1 Providers  |  0 Receivers
# South William: 1 Providers  |  1 Receivers
# South Zacharymouth: 1 Providers  |  0 Receivers
# Spenceland: 1 Providers  |  0 Receivers
# Steeleport: 1 Providers  |  0 Receivers
# Stephanieberg: 1 Providers  |  1 Receivers
# Stevenchester: 1 Providers  |  0 Receivers
# Stevensborough: 1 Providers  |  0 Receivers
# Steventown: 1 Providers  |  0 Receivers
# Steveport: 1 Providers  |  0 Receivers
# Stewartfurt: 1 Providers  |  0 Receivers
# Strongmouth: 1 Providers  |  0 Receivers
# Suzanneport: 1 Providers  |  0 Receivers
# Sylviabury: 1 Providers  |  0 Receivers
# Tamaraside: 1 Providers  |  0 Receivers
# Tammyside: 2 Providers  |  0 Receivers
# Tammystad: 1 Providers  |  0 Receivers
# Taylorchester: 1 Providers  |  0 Receivers
# Taylorfort: 1 Providers  |  1 Receivers
# Taylormouth: 1 Providers  |  0 Receivers
# Thomasfurt: 1 Providers  |  0 Receivers
# Thomasville: 1 Providers  |  0 Receivers
# Thorntonbury: 1 Providers  |  0 Receivers
# Timothychester: 1 Providers  |  0 Receivers
# Timothyview: 1 Providers  |  0 Receivers
# Tinamouth: 1 Providers  |  0 Receivers
# Toddberg: 1 Providers  |  0 Receivers
# Toddstad: 1 Providers  |  1 Receivers
# Torresfort: 1 Providers  |  0 Receivers
# Torresshire: 1 Providers  |  0 Receivers
# Tracyfort: 1 Providers  |  0 Receivers
# Tylerburgh: 1 Providers  |  0 Receivers
# Tylerton: 1 Providers  |  0 Receivers
# Tyronebury: 1 Providers  |  0 Receivers
# Valdezborough: 1 Providers  |  0 Receivers
# Valentineside: 1 Providers  |  0 Receivers
# Valenzuelaville: 1 Providers  |  0 Receivers
# Vazquezland: 1 Providers  |  0 Receivers
# Vazquezshire: 1 Providers  |  0 Receivers
# Velazquezview: 1 Providers  |  0 Receivers
# Villaborough: 1 Providers  |  0 Receivers
# Villastad: 1 Providers  |  0 Receivers
# Wadeville: 1 Providers  |  0 Receivers
# Walkerfurt: 1 Providers  |  0 Receivers
# Walterborough: 1 Providers  |  0 Receivers
# Walterton: 1 Providers  |  0 Receivers
# Wardton: 1 Providers  |  0 Receivers
# Washingtonville: 1 Providers  |  0 Receivers
# Watsonstad: 1 Providers  |  0 Receivers
# Watsonton: 1 Providers  |  0 Receivers
# Weberfurt: 1 Providers  |  0 Receivers
# West Abigailtown: 1 Providers  |  0 Receivers
# West Adam: 1 Providers  |  0 Receivers
# West Adammouth: 1 Providers  |  0 Receivers
# West Aliciabury: 1 Providers  |  0 Receivers
# West Amanda: 1 Providers  |  0 Receivers
# West Amandafurt: 1 Providers  |  0 Receivers
# West Anthonymouth: 1 Providers  |  0 Receivers
# West Ashleytown: 1 Providers  |  0 Receivers
# West Benjamin: 1 Providers  |  0 Receivers
# West Billborough: 1 Providers  |  0 Receivers
# West Brandon: 1 Providers  |  0 Receivers
# West Carolyn: 1 Providers  |  0 Receivers
# West Catherine: 1 Providers  |  0 Receivers
# West Charlesborough: 1 Providers  |  0 Receivers
# West Cherylfort: 1 Providers  |  0 Receivers
# West Christopher: 2 Providers  |  1 Receivers
# West Corey: 1 Providers  |  0 Receivers
# West Daniel: 1 Providers  |  0 Receivers
# West Danielborough: 1 Providers  |  0 Receivers
# West Danieltown: 1 Providers  |  0 Receivers
# West Dannyland: 1 Providers  |  0 Receivers
# West Dawn: 1 Providers  |  0 Receivers
# West Elizabethport: 1 Providers  |  0 Receivers
# West Erinport: 1 Providers  |  0 Receivers
# West Hunter: 1 Providers  |  0 Receivers
# West James: 1 Providers  |  2 Receivers
# West Jeffreyland: 1 Providers  |  0 Receivers
# West Juliabury: 1 Providers  |  0 Receivers
# West Julianburgh: 1 Providers  |  0 Receivers
# West Kara: 1 Providers  |  0 Receivers
# West Karen: 1 Providers  |  0 Receivers
# West Kelli: 1 Providers  |  0 Receivers
# West Kenneth: 1 Providers  |  0 Receivers
# West Kevin: 1 Providers  |  1 Receivers
# West Larry: 1 Providers  |  0 Receivers
# West Lauraborough: 2 Providers  |  0 Receivers
# West Lisamouth: 1 Providers  |  0 Receivers
# West Lucasville: 1 Providers  |  0 Receivers
# West Margaretfort: 1 Providers  |  0 Receivers
# West Matthew: 1 Providers  |  0 Receivers
# West Melissa: 1 Providers  |  0 Receivers
# West Melissastad: 1 Providers  |  0 Receivers
# West Miaside: 1 Providers  |  0 Receivers
# West Michael: 1 Providers  |  0 Receivers
# West Omar: 1 Providers  |  0 Receivers
# West Omarside: 1 Providers  |  0 Receivers
# West Pamelaborough: 1 Providers  |  0 Receivers
# West Peter: 1 Providers  |  0 Receivers
# West Peterborough: 1 Providers  |  0 Receivers
# West Phillip: 1 Providers  |  0 Receivers
# West Robert: 1 Providers  |  1 Receivers
# West Samantha: 1 Providers  |  0 Receivers
# West Samuelfurt: 1 Providers  |  0 Receivers
# West Sharonview: 1 Providers  |  0 Receivers
# West Stephaniemouth: 1 Providers  |  0 Receivers
# West Stephen: 1 Providers  |  0 Receivers
# West Stephenside: 1 Providers  |  0 Receivers
# West Stevenport: 1 Providers  |  0 Receivers
# West Tammy: 1 Providers  |  0 Receivers
# West Theresaberg: 1 Providers  |  0 Receivers
# West Thomas: 1 Providers  |  0 Receivers
# West Tinamouth: 1 Providers  |  0 Receivers
# West Trevorview: 1 Providers  |  0 Receivers
# West Tylerberg: 1 Providers  |  0 Receivers
# West Vanessafort: 1 Providers  |  0 Receivers
# West Whitneymouth: 1 Providers  |  0 Receivers
# Westbury: 1 Providers  |  0 Receivers
# Westmouth: 1 Providers  |  0 Receivers
# Wheelermouth: 1 Providers  |  0 Receivers
# Williamland: 1 Providers  |  0 Receivers
# Williammouth: 1 Providers  |  0 Receivers
# Williamschester: 1 Providers  |  0 Receivers
# Williamsfort: 1 Providers  |  2 Receivers
# Williamsland: 1 Providers  |  0 Receivers
# Williamsmouth: 1 Providers  |  0 Receivers
# Williamsonmouth: 1 Providers  |  0 Receivers
# Williamsshire: 1 Providers  |  0 Receivers
# Williamview: 2 Providers  |  0 Receivers
# Wilsonport: 1 Providers  |  0 Receivers
# Wilsonview: 1 Providers  |  0 Receivers
# Woodport: 1 Providers  |  0 Receivers
# Wrightville: 1 Providers  |  0 Receivers
# Yatesside: 1 Providers  |  0 Receivers
# Youngchester: 1 Providers  |  0 Receivers
# Zimmermanton: 1 Providers  |  0 Receivers
# Zimmermanville: 1 Providers  |  0 Receivers

# %% [markdown]
#                  2.Which type of food provider (restaurant, grocery store, etc.) contributes the most food

# %%
query=""" 
SELECT 
    p.Type,
    SUM(f.Quantity) AS Food_Total
FROM foodlistings f
JOIN providers p on f.Provider_ID=p.Provider_ID
GROUP BY p.Type
ORDER BY Food_Total DESC
LIMIT 1;
"""


    
cursor.execute(query)
result = cursor.fetchone()  # Only one row expected due to LIMIT 1

# Unpack and print the result
if result:
    type_, total_food = result
    print(f"Top Provider Type: {type_} | Total Food Quantity: {total_food}")
else:
    print("No data found.")
# Out:
# Top Provider Type: Restaurant | Total Food Quantity: 1142295

# %% [markdown]
#         3. What is the contact information of food providers in a specific city?

# %%
city_name=input("Enter city name to get contact information of food providers in that city: ")
query=""" 
SELECT DISTINCT Name,Contact
FROM providers p
WHERE City=%s;

"""
cursor.execute(query, (city_name,))
results = cursor.fetchall()
for name, contact in results:
    print(f"Name: {name} | Contact: {contact}")
# Out:
# Name: Clark, Prince and Williams | Contact: 556.944.8935x401

# %% [markdown]
#                 4.Which receivers have claimed the most food?

# %%
query=""" 
SELECT r.Name, SUM(f.Quantity) AS Food_Claimed
FROM claims c
JOIN receivers r ON c.Receiver_ID =r.receiver_ID
JOIN foodlistings f ON c.Food_ID=f.Food_ID
WHERE c.Status='Completed' 
GROUP BY r.Name
ORDER BY Food_Claimed DESC
LIMIT 1;


"""
cursor.execute(query)
result = cursor.fetchone() 

if result:
    name_, food_claimed = result
    print(f"Top Receiver: {name_} | Total Food Quantity: {food_claimed}")
else:
    print("No data found.")
# Out:
# Top Receiver: Derek Potter | Total Food Quantity: 45738

# %% [markdown]
#     B. FOOD LSITINGS AND AVAILABILITY

# %% [markdown]
#         5.What is the total quantity of food available from all providers?

# %%
query="""
SELECT SUM(f.quantity) as Total_Food
FROM foodlistings f

 """

cursor.execute(query)
result = cursor.fetchone() 

if result:
    Total_Food = result
    print(f" Total Food Quantity: {Total_Food}")
else:
    print("No data found.")
# Out:
#  Total Food Quantity: (Decimal('283734'),)

# %% [markdown]
#         6.Which city has the highest number of food listings?

# %%
query=''' 
SELECT Location AS City, COUNT(*) AS Max_Listings
FROM foodlistings
GROUP BY Location
ORDER BY Max_Listings
LIMIT 1;

'''
cursor.execute(query)
result = cursor.fetchone() 

if result:
    Max_Listings = result
    print(f" City with Highest Number of Food listings: {Max_Listings}")
else:
    print("No data found.")
# Out:
#  City with Highest Number of Food listings: ('South Kellyville', 11)

# %% [markdown]
#             7. What are the most commonly available food types?

# %%
query=''' 
SELECT f.Food_Type, COUNT(*) AS Common_Type
FROM foodlistings f
GROUP BY f.Food_Type
ORDER BY Common_Type
LIMIT 1;
'''
cursor.execute(query)
result = cursor.fetchone() 

if result:
    Common_Type= result
    print(f" Commonly Available Food Types: {Common_Type}")
else:
    print("No data found.")
# Out:
#  Commonly Available Food Types: ('Non-Vegetarian', 3630)

# %% [markdown]
# CLAIMS AND DISTRIBUTION

# %% [markdown]
#             8.How many food claims have been made for each food item?

# %%
query='''   
SELECT c.Food_ID, COUNT(*) AS Num_Claims
FROM claims c
GROUP BY Food_ID
ORDER BY Num_claims;

'''
cursor.execute(query)
results = cursor.fetchall()
for Food_ID, Num_Claims in results:
    print(f"Food ID: {Food_ID} | Claims: {Num_Claims}")
# Out:
# Food ID: 61 | Claims: 3
# Food ID: 273 | Claims: 3
# Food ID: 735 | Claims: 3
# Food ID: 382 | Claims: 3
# Food ID: 278 | Claims: 3
# Food ID: 669 | Claims: 3
# Food ID: 694 | Claims: 3
# Food ID: 426 | Claims: 3
# Food ID: 792 | Claims: 3
# Food ID: 281 | Claims: 3
# Food ID: 959 | Claims: 3
# Food ID: 586 | Claims: 3
# Food ID: 193 | Claims: 3
# Food ID: 905 | Claims: 3
# Food ID: 713 | Claims: 3
# Food ID: 597 | Claims: 3
# Food ID: 757 | Claims: 3
# Food ID: 825 | Claims: 3
# Food ID: 556 | Claims: 3
# Food ID: 746 | Claims: 3
# Food ID: 895 | Claims: 3
# Food ID: 543 | Claims: 3
# Food ID: 990 | Claims: 3
# Food ID: 119 | Claims: 3
# Food ID: 424 | Claims: 3
# Food ID: 310 | Claims: 3
# Food ID: 526 | Claims: 3
# Food ID: 708 | Claims: 3
# Food ID: 641 | Claims: 3
# Food ID: 805 | Claims: 3
# Food ID: 197 | Claims: 3
# Food ID: 790 | Claims: 3
# Food ID: 829 | Claims: 3
# Food ID: 378 | Claims: 3
# Food ID: 136 | Claims: 3
# Food ID: 741 | Claims: 3
# Food ID: 469 | Claims: 3
# Food ID: 162 | Claims: 3
# Food ID: 864 | Claims: 3
# Food ID: 108 | Claims: 3
# Food ID: 252 | Claims: 3
# Food ID: 318 | Claims: 3
# Food ID: 660 | Claims: 3
# Food ID: 650 | Claims: 3
# Food ID: 493 | Claims: 3
# Food ID: 46 | Claims: 3
# Food ID: 648 | Claims: 3
# Food ID: 668 | Claims: 3
# Food ID: 149 | Claims: 3
# Food ID: 769 | Claims: 3
# Food ID: 795 | Claims: 3
# Food ID: 359 | Claims: 3
# Food ID: 582 | Claims: 3
# Food ID: 579 | Claims: 9
# Food ID: 427 | Claims: 9
# Food ID: 609 | Claims: 9
# Food ID: 152 | Claims: 9
# Food ID: 335 | Claims: 9
# Food ID: 670 | Claims: 9
# Food ID: 479 | Claims: 9
# Food ID: 837 | Claims: 9
# Food ID: 558 | Claims: 9
# Food ID: 380 | Claims: 9
# Food ID: 615 | Claims: 9
# Food ID: 822 | Claims: 9
# Food ID: 96 | Claims: 9
# Food ID: 107 | Claims: 9
# Food ID: 241 | Claims: 9
# Food ID: 528 | Claims: 9
# Food ID: 730 | Claims: 9
# Food ID: 398 | Claims: 9
# Food ID: 743 | Claims: 9
# Food ID: 84 | Claims: 9
# Food ID: 271 | Claims: 9
# Food ID: 151 | Claims: 9
# Food ID: 947 | Claims: 9
# Food ID: 606 | Claims: 9
# Food ID: 632 | Claims: 9
# Food ID: 115 | Claims: 9
# Food ID: 230 | Claims: 9
# Food ID: 215 | Claims: 9
# Food ID: 599 | Claims: 9
# Food ID: 744 | Claims: 9
# Food ID: 622 | Claims: 9
# Food ID: 636 | Claims: 9
# Food ID: 945 | Claims: 9
# Food ID: 224 | Claims: 9
# Food ID: 30 | Claims: 9
# Food ID: 674 | Claims: 12
# Food ID: 190 | Claims: 12
# Food ID: 832 | Claims: 12
# Food ID: 886 | Claims: 12
# Food ID: 251 | Claims: 12
# Food ID: 797 | Claims: 12
# Food ID: 925 | Claims: 12
# Food ID: 882 | Claims: 12
# Food ID: 696 | Claims: 12
# Food ID: 35 | Claims: 12
# Food ID: 915 | Claims: 12
# Food ID: 217 | Claims: 12
# Food ID: 981 | Claims: 12
# Food ID: 861 | Claims: 12
# Food ID: 520 | Claims: 12
# Food ID: 92 | Claims: 12
# Food ID: 486 | Claims: 15
# Food ID: 463 | Claims: 15
# Food ID: 548 | Claims: 15

# %% [markdown]
#          9. Which provider has had the highest number of successful food claims?

# %%
query=''' 
SELECT p.Provider_ID, COUNT(*) AS Succesful_Claims
FROM claims c
JOIN foodlistings f ON c.Food_ID=f.Food_ID
JOIN providers p ON p.Provider_ID= f.Provider_ID
WHERE c.Status='Completed'
GROUP BY p.Provider_ID
ORDER BY Succesful_Claims DESC
LIMIT 1;

'''
cursor.execute(query)
result = cursor.fetchone() 
if result:
    providerID_, successful_claims = result
    print(f"Provider with the highest food claims: {providerID_} | Total Successful Claims: {successful_claims}")
else:
    print("No data found.")
# Out:
# Provider with the highest food claims: 709 | Total Successful Claims: 2475

# %% [markdown]
#                 10. What percentage of food claims are completed vs. pending vs. canceled?

# %%
query=''' 
SELECT 
        Status,
        COUNT(*) AS count,
        ROUND(100.0*COUNT(*)/(SELECT COUNT(*) FROM claims),2) AS Percentage
FROM claims


GROUP BY Status

ORDER BY 
        Percentage DESC;

'''

cursor.execute(query)
results = cursor.fetchall()

print(f"{'Status':<12} | {'Claims':<6} | {'Percentage':<10}")
print("-" * 35)

for status, count, percentage in results:
    print(f"{status:<12} | {count:<6} | {percentage:<10.2f}%")
# Out:
# Status       | Claims | Percentage
# -----------------------------------
# Completed    | 1017   | 33.90     %
# Cancelled    | 1008   | 33.60     %
# Pending      | 975    | 32.50     %

# %% [markdown]
#         ANALYSIS AND INSIGHTS

# %% [markdown]
#                        11. What is the average quantity of food claimed per receiver?

# %%
query=''' 
SELECT r.Name, AVG(f.Quantity) AS Avg_Claimed
FROM claims c
JOIN receivers r ON c.receiver_ID=r.receiver_ID
JOIN foodlistings f ON c.Food_ID=f.Food_ID
GROUP BY r.Name

'''

cursor.execute(query)
results = cursor.fetchall()

print(f"{'Name':<30} | {'Quantity':<6}")
print("-" * 100)

for name_, Avg_Claimed in results:
    print(f"{name_:<30} | {Avg_Claimed:<6}")
# Out:
# Name                           | Quantity
# ----------------------------------------------------------------------------------------------------
# Donald Gomez                   | 35.5000
# Laurie Ramos                   | 47.0000
# Ashley Mckee                   | 26.0000
# Erika Rose                     | 30.5000
# Mandy Sutton PhD               | 15.0000
# Kenneth Baker                  | 31.0000
# Emily Turner                   | 34.0000
# Mary Salazar                   | 26.5000
# Jennifer Bishop                | 33.0000
# Brian Fischer                  | 28.0000
# Donald Kelly                   | 44.0000
# Elizabeth Lewis                | 4.0000
# Kimberly Lindsey               | 14.0000
# Johnny Page                    | 34.0000
# Mary Franklin                  | 29.0000
# Rose Powell                    | 26.0000
# Audrey Perez                   | 45.0000
# Anita Kerr                     | 26.0000
# Megan Alvarez                  | 13.0000
# James Castaneda                | 14.0000
# Angel Adams                    | 49.0000
# Alexander Mullins              | 49.0000
# Maria Jacobs                   | 27.0000
# Bobby Perry                    | 17.0000
# Andrew Lawson                  | 35.0000
# Derek Potter                   | 33.0000
# Taylor Dean                    | 27.0000
# Jennifer Graham                | 26.0000
# Brian Gonzales                 | 26.0000
# Cheryl Dillon                  | 25.5000
# Cassandra Owens                | 5.0000
# Deborah Smith                  | 42.0000
# Christopher Lozano             | 16.0000
# Julia Madden                   | 44.0000
# Alicia Thomas                  | 26.6667
# Nichole Lewis                  | 39.5000
# David Turner                   | 31.0000
# Cody Gardner                   | 15.5000
# Jade Jackson                   | 41.0000
# Wesley Thompson                | 23.0000
# Scott Brown                    | 49.0000
# Charles Davidson               | 25.3333
# Patricia Smith                 | 42.0000
# Nicholas Smith                 | 9.0000
# Juan Spencer                   | 6.0000
# Jessica Grant                  | 30.0000
# Tammy Walker MD                | 32.0000
# Eric Ryan DDS                  | 15.0000
# Alvin West                     | 24.7500
# Allison Bray                   | 22.6667
# Timothy Patel DVM              | 49.0000
# Michael Walls                  | 23.0000
# Nathan May                     | 26.5000
# Brian Cowan                    | 47.0000
# Nancy Silva                    | 50.0000
# Melissa Little                 | 49.0000
# Nicole Reid                    | 19.0000
# Daniel Burton                  | 38.0000
# Karen Cruz                     | 37.0000
# Victor Reyes                   | 37.0000
# Trevor Wilson                  | 25.0000
# Jessica Morris                 | 7.0000
# Rachel Nguyen                  | 17.0000
# Brady Lopez                    | 42.0000
# Jonathan Young                 | 22.3333
# Mark Lee                       | 21.0000
# Matthew Tran                   | 33.0000
# Autumn Reed                    | 16.0000
# Stacy Mayo                     | 24.5000
# Randall Robbins                | 30.5000
# Mrs. Paula Jones               | 23.5000
# Mark Hartman                   | 7.0000
# Walter Carter                  | 18.0000
# Robin Ross                     | 23.0000
# Michael Johnson                | 7.5000
# Scott Hunter                   | 31.4000
# Angela Wyatt                   | 49.0000
# Mrs. Kristin Adams DDS         | 19.6667
# Lisa Pitts                     | 50.0000
# Edward Cook                    | 38.5000
# Derrick Curtis                 | 33.0000
# Jennifer Johnson               | 33.5000
# Mrs. Emily Smith DVM           | 31.5000
# Randy Roach                    | 24.5000
# Cynthia Horton                 | 12.0000
# Joseph Williams                | 26.0000
# Deanna Daniels                 | 30.5000
# Robert Burke                   | 24.0000
# Michael Curtis                 | 4.5000
# Jeanne Benjamin                | 22.5000
# Kristina Simpson               | 31.0000
# Daniel Moore                   | 34.5000
# Joseph Davis                   | 29.5000
# Brendan Vargas                 | 31.0000
# Donna Williams                 | 40.6667
# Robin Pena                     | 40.0000
# Gary Adams                     | 19.0000
# Kelsey Smith                   | 41.0000
# Martha Flores                  | 20.0000
# Michael Carter                 | 29.0000
# Donald Bender                  | 5.0000
# Carmen Barker                  | 29.0000
# Wanda Wise                     | 13.5000
# Stephanie Mathews              | 30.0000
# Linda Banks                    | 14.5000
# Kristine Martin                | 29.0000
# Aaron Keller                   | 39.0000
# Carlos Lawrence                | 15.0000
# Christine Patterson            | 21.5000
# Kimberly Hamilton              | 44.0000
# Shane Stein                    | 46.0000
# Laura Marshall                 | 18.0000
# Jennifer Schmidt               | 36.5000
# Dustin Johnson                 | 48.0000
# Anna Buckley                   | 35.3333
# Kristina Vargas                | 36.0000
# Barbara Velasquez              | 35.0000
# Eric Ramos                     | 26.0000
# Michael Keller                 | 46.0000
# Donna Hughes                   | 33.0000
# Sylvia Stanley                 | 44.0000
# Kerry Jones                    | 13.0000
# Cody Martin                    | 28.0000
# Mrs. Stacey Morales MD         | 18.5000
# Kimberly Nelson                | 26.0000
# Brian Hoffman                  | 3.0000
# Jacob Orozco                   | 31.0000
# Brian Davis                    | 20.0000
# Tammy Boone                    | 24.0000
# Samuel Lewis                   | 25.6667
# Elizabeth Collins              | 7.0000
# Ricardo Roberts                | 9.0000
# Debra Murray                   | 29.6667
# Tara Johns                     | 42.0000
# William Frederick              | 21.4000
# Harold Bowen                   | 22.0000
# Seth Esparza                   | 25.0000
# Ricky Walker                   | 37.0000
# Melissa Smith                  | 48.0000
# John Reeves                    | 38.0000
# Patrick Campbell               | 38.5000
# Brandi Buckley                 | 14.0000
# Tara Graham                    | 20.0000
# Heather Silva                  | 42.0000
# Yvette Huffman                 | 45.0000
# Patricia Stevens               | 34.6667
# Anthony Guerra                 | 11.0000
# William Barnes                 | 47.0000
# Mary Hopkins                   | 33.0000
# Nicole Mueller                 | 33.0000
# Kelly Buchanan                 | 42.0000
# Victor Crawford                | 24.3333
# Regina Munoz                   | 12.0000
# Tracy Douglas                  | 42.0000
# Kyle Kerr                      | 17.0000
# Allison Martinez               | 10.0000
# Mr. Robert Rivera II           | 11.0000
# Alex White                     | 18.0000
# Jennifer Hughes                | 6.5000
# John Byrd                      | 29.5000
# Leslie Acevedo                 | 40.0000
# Marissa Fischer                | 29.5000
# Ashley Martinez                | 30.0000
# Arthur Thomas                  | 26.0000
# Jennifer Mccoy                 | 49.0000
# Matthew Simmons PhD            | 4.0000
# Betty Reid                     | 23.2500
# David Carney                   | 28.5000
# Dennis Schultz                 | 18.0000
# Dr. Matthew Hughes DDS         | 28.5000
# Kevin Blair                    | 22.0000
# Ernest Cox                     | 13.0000
# Justin Santos                  | 32.0000
# Miss Mary Turner               | 16.0000
# Teresa Jackson                 | 26.3333
# Susan Green                    | 18.6667
# Christine Bell                 | 24.6667
# Pamela Harris                  | 21.0000
# Robert Chavez                  | 7.0000
# Jose Rivas                     | 31.0000
# Daniel Williams                | 50.0000
# Julie Brown                    | 25.0000
# Whitney Evans                  | 17.0000
# Jacqueline Turner              | 28.0000
# Lindsey Lewis                  | 17.5000
# Jane Davis                     | 32.6667
# Erika Lopez                    | 38.5000
# Alexander Walsh                | 27.6667
# Natasha Harper                 | 32.0000
# Eric Mays                      | 21.6667
# Nicholas Harrison              | 28.0000
# Mrs. Valerie Hartman           | 19.0000
# Marcus Gregory                 | 37.0000
# Tina Banks                     | 43.0000
# Steven Griffin                 | 44.5000
# Jennifer Kennedy               | 19.0000
# Michael Vargas                 | 46.0000
# Brandon Riley                  | 26.0000
# Karen Stafford                 | 17.0000
# Timothy Martin                 | 3.0000
# Nathan Gonzales                | 44.0000
# David Castro                   | 21.5000
# Brian Hill                     | 23.5000
# Justin Powell                  | 42.0000
# Kim Gamble                     | 20.0000
# Jorge Young                    | 11.0000
# Karen Reeves MD                | 7.0000
# Michael Roberson               | 12.0000
# Timothy Garrett                | 26.6667
# Emily Sandoval                 | 45.0000
# Mary Harrington                | 8.0000
# Debbie Cox                     | 15.0000
# Micheal Peterson               | 39.0000
# Patrick Jenkins                | 14.0000
# Erin Foster                    | 11.0000
# Julie Lewis                    | 37.0000
# Chelsea Powell                 | 33.5000
# Timothy Chavez                 | 21.0000
# Andrea Meyer                   | 23.5000
# Miss Jamie Gonzalez DDS        | 22.5000
# Ricky Harmon                   | 17.0000
# Richard Patterson              | 32.3333
# Eileen Scott                   | 27.5000
# Alexandra Owens                | 20.2500
# Destiny Maldonado              | 39.6667
# Kimberly Wilson                | 23.0000
# Drew Edwards                   | 32.0000
# Jeremy Christensen             | 7.0000
# Kimberly Cox                   | 9.0000
# Anne Stone                     | 19.0000
# Ashley Bell                    | 4.0000
# Taylor Wolfe                   | 25.0000
# William Fox                    | 12.0000
# Tiffany Rodriguez              | 40.0000
# Michael Dixon                  | 33.0000
# Brian Morales                  | 34.0000
# Alexander Dean                 | 30.0000
# Amy Perez                      | 32.5000
# Alexandra Rogers               | 30.0000
# David Sellers DVM              | 31.6667
# Joseph Knapp                   | 8.0000
# Margaret Lloyd                 | 7.5000
# Earl Eaton                     | 4.0000
# Ronald Norton                  | 19.5000
# Amy Brown                      | 34.0000
# Savannah Neal                  | 17.0000
# Brenda Green                   | 38.0000
# Matthew Wright                 | 32.0000
# Peter Allen                    | 5.0000
# Meagan Hughes                  | 18.0000
# James Kennedy                  | 35.0000
# Gary Andrews                   | 14.0000
# Trevor Lam                     | 21.0000
# Shawn Gibson                   | 23.6667
# Scott Proctor                  | 35.5000
# Margaret Mccullough            | 13.3333
# Mary Lewis                     | 22.0000
# Samantha Salinas               | 4.0000
# Randy Martinez                 | 39.5000
# Matthew Mendez                 | 34.0000
# Andrea Morris                  | 33.0000
# Antonio Murphy                 | 12.0000
# Brian Blankenship              | 10.0000
# Michael Lewis                  | 9.0000
# Peggy Knight                   | 50.0000
# Melissa Mclaughlin             | 38.0000
# Danny Randolph                 | 30.0000
# Anthony Cochran                | 34.5000
# Lydia Phillips                 | 15.6667
# Diana Blair                    | 19.0000
# Mr. William Hunt               | 43.0000
# Justin Lopez                   | 27.0000
# Mark Lewis                     | 29.5000
# Amy Barker                     | 41.0000
# Jennifer Clark                 | 7.0000
# Laurie Alvarez                 | 32.0000
# Nicole Williams                | 20.5000
# Terry Fernandez                | 30.6667
# Sheri Johnson                  | 3.0000
# Courtney Whitney               | 16.3333
# Natalie Navarro                | 27.0000
# Bruce Alexander                | 17.6667
# Peter Gonzalez                 | 41.5000
# Paul Carter                    | 38.0000
# Christina Caldwell             | 23.0000
# Sean Wolf                      | 32.0000
# Oscar Bauer                    | 23.3333
# Jimmy Morton                   | 46.0000
# Meredith Griffin               | 23.0000
# Renee Campbell                 | 32.5000
# Rachel Carson                  | 10.0000
# Christopher Wright             | 50.0000
# Justin Lee                     | 28.0000
# Samuel Mendez                  | 42.0000
# Taylor Estrada                 | 11.0000
# Cassandra Foster               | 4.0000
# Gary Torres                    | 13.0000
# Alvin Day Jr.                  | 21.0000
# Paul Lee                       | 17.0000
# James Gardner                  | 17.0000
# Andrea Hansen                  | 25.0000
# Diana Fisher                   | 25.0000
# Austin Smith                   | 6.0000
# Benjamin Soto                  | 35.0000
# Timothy Browning               | 9.0000
# Joseph Smith                   | 42.0000
# Mary Morrow                    | 21.0000
# Steven Armstrong               | 32.0000
# Christine Davis                | 20.3333
# Heather Stewart                | 32.0000
# Cory Schmidt MD                | 43.0000
# Nicholas Peterson              | 42.5000
# Rebecca Mcbride                | 25.0000
# Sandy Ward                     | 12.0000
# John Murray                    | 6.0000
# Lauren Golden                  | 43.0000
# Frank Olson                    | 43.0000
# James Hernandez II             | 39.0000
# Michael English                | 31.5000
# Felicia Collier                | 26.0000
# Meredith Hull                  | 3.0000
# Maria Singh                    | 35.0000
# Amber Hobbs                    | 26.0000
# Cindy Green PhD                | 17.0000
# Shelly Castillo                | 5.5000
# Stephen Harris                 | 35.0000
# John Williams                  | 13.0000
# Joseph Johnson                 | 24.5000
# Alexis Rodriguez               | 8.0000
# James Lewis                    | 4.0000
# Becky Hernandez                | 22.0000
# Paige Lewis                    | 26.0000
# Kiara Martinez                 | 19.0000
# Angela Knight                  | 21.0000
# Spencer Roberts                | 24.0000
# Danny Palmer                   | 15.0000
# Jeffrey Turner                 | 47.0000
# Brittany Williams              | 17.0000
# Carl Brewer                    | 33.0000
# Rachel Arnold                  | 45.0000
# Janet Newton                   | 18.3333
# Kellie Hart                    | 11.0000
# Laura Leach                    | 37.0000
# Kimberly Duncan                | 6.0000
# Amber Arellano                 | 31.0000
# Rebecca Chan                   | 31.0000
# Mr. Jonathan Williams          | 36.0000
# Jason Lowe                     | 27.5000
# Christopher Sellers            | 15.0000
# Shannon Jensen                 | 4.6667
# Eric Carrillo                  | 27.0000
# Robert Moses                   | 30.0000
# Tyler Christensen              | 4.0000
# Jonathon Gregory               | 17.3333
# Matthew Brown                  | 36.0000
# Lisa Kim                       | 14.0000
# Edward Lopez                   | 46.0000
# Tammy Brown                    | 9.0000
# Dustin Stark                   | 46.0000
# David Spence                   | 27.0000
# Felicia Glover                 | 18.0000
# Kyle Scott                     | 32.6667
# James Brown                    | 27.6667
# Matthew Morgan                 | 47.0000
# Nancy Jones                    | 50.0000
# Matthew Webb                   | 38.2000
# Nicholas Tucker                | 43.0000
# Jose Vance                     | 41.0000
# Kenneth Barnes                 | 2.0000
# Vanessa Johnson                | 18.6667
# Bridget Williams               | 14.0000
# Michael Ford                   | 28.0000
# Eugene Beltran                 | 16.0000
# Emma Anderson                  | 16.0000
# Christopher Garcia             | 14.0000
# Kathleen Watkins               | 27.0000
# Donna Chang                    | 22.0000
# Karen Williamson               | 10.0000
# Joshua Hooper                  | 1.0000
# John Reynolds                  | 2.0000
# Jordan Hart                    | 26.0000
# Mary Wilson                    | 37.5000
# John Warner                    | 46.5000
# Jacob Gibbs                    | 39.5000
# Emily Gallagher                | 19.0000
# Cassandra Yoder                | 49.0000
# Tracy Bass                     | 19.0000
# Julie Dickerson                | 36.0000
# Kristie Townsend               | 30.0000
# Jason Taylor                   | 22.0000
# Timothy Burns                  | 25.0000
# Monica Phillips                | 27.0000
# Melissa Lee                    | 37.0000
# Robert Kim                     | 23.0000
# Rachel Rios                    | 28.0000
# Beth Phillips                  | 14.0000
# Laura Robertson                | 37.5000
# David Kennedy                  | 22.0000
# Lee Nunez                      | 9.5000
# Caitlin Cobb                   | 17.0000
# Robert Becker                  | 34.0000
# Adam Moore                     | 27.3333
# Anthony Garcia                 | 32.4000
# Lisa Cruz                      | 35.0000
# Elizabeth Cochran              | 30.5000
# Sharon Martin                  | 31.0000
# James Miller                   | 19.0000
# Taylor Miller                  | 35.0000
# Pamela Finley                  | 42.0000
# Karen Cain                     | 43.0000
# Cody Meyer                     | 43.0000
# Scott Schroeder                | 16.3333
# Michael Petersen               | 15.0000
# Victoria Torres                | 28.0000
# Jeffrey Wilson                 | 13.0000
# Madison Myers                  | 33.0000
# Charles Morris                 | 29.0000
# Jeffrey Cooper                 | 16.0000
# Samantha Ellison               | 48.0000
# Kylie Young                    | 33.0000
# Kelly Pierce                   | 36.0000
# Jennifer Wright                | 15.5000
# Scott Craig                    | 26.0000
# Michelle Reed                  | 20.0000
# Jessica Stephens               | 25.5000
# Michael Cox                    | 11.0000
# Mary Anderson                  | 4.0000
# Brian Reed                     | 38.0000
# Robert Stewart                 | 48.0000
# Glenn Anthony                  | 20.5000
# Andrew Gray                    | 42.0000
# Terrence Wagner                | 7.0000
# Kyle Johnson                   | 25.5000
# Kristopher Mendoza             | 28.3333
# Jo Martinez                    | 17.0000
# Christopher Diaz               | 30.0000
# Robert Abbott                  | 40.5000
# Amanda Brown                   | 8.0000
# Ashley Harris                  | 34.6667
# Dana Williams                  | 36.0000
# Ashley Clark                   | 45.0000
# Jessica Camacho                | 31.0000
# Justin Anderson                | 26.0000
# Katherine Houston              | 36.0000
# Jose Cooper                    | 7.0000
# David Mendoza                  | 12.0000
# Joshua Mendoza                 | 28.0000
# Veronica Adams                 | 37.0000
# Lori Peters                    | 13.0000
# Darius Reid                    | 27.0000
# Danny Brown                    | 17.0000
# Scott Smith                    | 35.0000
# Jeremy Robinson                | 29.0000
# Jeffrey Stafford               | 23.0000
# Cory Johnson                   | 7.0000
# Bridget Hill                   | 9.0000
# Kristen Foster                 | 31.0000
# Steven Shaffer                 | 8.0000
# Aaron Rios                     | 21.0000
# Mary Evans                     | 35.0000
# Amber Cruz                     | 18.0000
# Jean Woods                     | 46.5000
# Matthew Davis                  | 23.5000
# Holly Aguilar                  | 36.0000
# Thomas Myers                   | 34.0000
# Brian Hardy                    | 35.0000
# Carrie Hess                    | 2.5000
# Tammy Fletcher                 | 13.0000
# Shelby Rice                    | 15.0000
# Rachel Pena                    | 26.0000
# Hannah Reynolds                | 37.5000
# Donald Caldwell                | 43.5000
# Michelle Riley                 | 39.0000
# Cindy Robinson DDS             | 15.0000
# Amanda Kline                   | 1.0000
# Ann Odonnell                   | 30.5000
# Christopher Gonzalez           | 49.0000
# Abigail Crawford               | 25.6667
# Matthew Cordova                | 4.0000
# Katelyn Proctor                | 34.0000
# Lindsey Mathis                 | 7.0000
# Michael Townsend               | 34.3333
# Katrina Cruz                   | 44.0000
# Gregory Rodriguez              | 19.0000
# Kelly Walls                    | 4.0000
# Victor Diaz                    | 32.6667
# Kimberly Ware                  | 29.0000
# Mary Escobar                   | 22.0000
# Donna Terry                    | 21.0000
# Jodi Lee                       | 24.5000
# Dr. Wendy Terrell              | 9.0000
# John Harris                    | 18.3333
# Jacob Horton                   | 26.0000
# Mark Ward                      | 33.0000
# Matthew Thornton               | 7.0000
# Chad Vaughn                    | 23.0000
# Rebecca Lucas                  | 23.0000
# Sharon Wood                    | 26.0000
# Alex Leon                      | 14.0000
# Taylor Mann                    | 20.0000
# Debra Webster                  | 30.0000
# Allison Pennington             | 31.0000
# Caitlin Bennett                | 39.5000
# Angela Hall                    | 40.5000
# Samantha Gomez                 | 12.5000
# Jason Hughes                   | 28.0000
# Donald Anderson                | 32.0000
# Victor Ward                    | 15.0000
# Donald Moore                   | 6.0000
# Ashley Silva                   | 11.5000
# Samantha Sherman               | 19.0000
# Mr. Joseph Herring             | 20.5000
# Brandon Rice                   | 20.5000
# Patricia Joseph                | 37.0000
# Brian Johnson                  | 5.0000
# Mark Miller                    | 15.5000
# Danielle Bullock               | 14.0000
# Pamela Scott                   | 22.0000
# Thomas Villanueva              | 50.0000
# Joanna Black                   | 19.5000
# Steve Kirby                    | 26.0000
# Thomas Sanchez                 | 28.5000
# Kristi Rodriguez               | 40.0000
# Patricia Hardy                 | 41.5000
# Alexis Hayes                   | 12.0000
# Angelica Simmons               | 26.0000
# Brittany Taylor                | 35.0000
# Matthew Curtis                 | 24.5000
# Amanda Cain                    | 25.5000
# Cheyenne Ramsey                | 42.0000
# April Miller                   | 19.0000

# %% [markdown]
#           12. Which meal type (breakfast, lunch, dinner, snacks) is claimed the most?

# %%
query=''' 
SELECT Meal_Type, COUNT(*) AS Num_claims
FROM foodlistings f
JOIN claims c ON f.Food_ID=c.Food_ID
GROUP BY Meal_type
ORDER BY Num_claims DESC
LIMIT 1;

'''
cursor.execute(query)
results=cursor.fetchone()
meal_type_, Num_claims=results
print(f"Most Claimed Type of Meal: {meal_type_}\nQuantity: {Num_claims}")
# Out:
# Most Claimed Type of Meal: Breakfast
# Quantity: 9174

# %% [markdown]
#                 13.What is the total quantity of food donated by each provider?

# %%
query=''' 
SELECT p.Provider_ID, COUNT(*) AS Num_Donated
FROM providers p
JOIN foodlistings f ON p.Provider_ID=f.Provider_ID
GROUP BY Provider_ID
ORDER BY Num_Donated;
'''
cursor.execute(query)
results=cursor.fetchall()
print(f"{'ID':<30} | {'Quantity':<6}")
print("-" * 70)

for providerID__, Num_Donated in results:
    print(f"{providerID_:<30} | {Num_Donated:<6}")
# Out:
# ID                             | Quantity
# ----------------------------------------------------------------------
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 165
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 330
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 495
# 709                            | 660
# 709                            | 660
# 709                            | 660
# 709                            | 660
# 709                            | 660
# 709                            | 660
# 709                            | 660
# 709                            | 660
# 709                            | 660
# 709                            | 660
# 709                            | 660
# 709                            | 660
# 709                            | 660
# 709                            | 825
# 709                            | 825
# 709                            | 825
# 709                            | 990

# %% [markdown]
#                 14. Average number of claims per receiver

# %%
query=''' 
SELECT Receiver_ID, COUNT(*) AS total_claims
FROM claims
GROUP BY Receiver_ID

'''
cursor.execute(query)
results=cursor.fetchall()
for total_claims, recevierID_ in results:
    print(f"{recevierID_}   |  {total_claims}")
# Out:
# 9   |  908
# 6   |  391
# 6   |  492
# 6   |  933
# 3   |  229
# 6   |  607
# 6   |  256
# 6   |  900
# 3   |  807
# 3   |  975
# 9   |  118
# 3   |  739
# 6   |  959
# 9   |  233
# 6   |  97
# 3   |  836
# 3   |  588
# 6   |  729
# 6   |  399
# 3   |  88
# 12   |  493
# 3   |  757
# 3   |  526
# 9   |  717
# 6   |  10
# 3   |  487
# 6   |  189
# 6   |  769
# 9   |  228
# 3   |  546
# 15   |  371
# 6   |  386
# 3   |  271
# 9   |  93
# 3   |  562
# 3   |  920
# 3   |  380
# 9   |  923
# 6   |  789
# 3   |  336
# 9   |  306
# 9   |  31
# 3   |  569
# 6   |  412
# 6   |  48
# 3   |  943
# 3   |  984
# 3   |  211
# 3   |  746
# 3   |  967

# %% [markdown]
#                 15. Providers with most diverse food offerings

# %%
query=''' 
SELECT 
        p.Name AS Pname,
        COUNT(DISTINCT f.Food_type) AS Food_Type_Count
FROM foodlistings f
JOIN providers p ON p.Provider_ID =f.Provider_ID
GROUP BY p.Name
ORDER BY Food_Type_Count DESC
LIMIT 1;
'''

cursor.execute(query)
results=cursor.fetchall()

for Provider_ID, Food_Type_Count in results:
    print(f"{Provider_ID}    {Food_Type_Count}  ")
# Out:
# Anderson, Nicholson and Bruce    3

# %% [markdown]
#                 16.Top 5 active Food providers based on 'Completed' Status of Claims

# %%
query=''' 
SELECT 
    p.Provider_ID,
    p.Name as Provider_name,
    COUNT(c.Claim_ID)  AS Claim_num
FROM
    providers p

JOIN foodlistings f ON p.Provider_ID=f.Provider_ID
JOIN claims c ON f.Food_ID=c.Food_ID
WHERE c.Status='Completed'
GROUP BY 
    p.Provider_ID,p.Name
ORDER BY 
    Claim_num DESC
LIMIT 5; 

'''


cursor.execute(query)
results=cursor.fetchall()

for Provider_ID_, Name_, Claim_num in results:
    print(f"{Provider_ID_}   {Name_}    {Claim_num}  ")
# Out:
# 709   Barry Group    2475
# 241   Harper, Blake and Alexander    1980
# 752   Butler-Richardson    1980
# 596   Barnes, Castro and Curtis    1980
# 967   Miller Inc    1980

# %% [markdown]
#                 17. Distribution of Claims by Status

# %%
query=''' 
SELECT 
        Status,
        COUNT(Claim_ID) AS Claim_Count,
        ROUND(COUNT(Claim_ID)/(SELECT COUNT(*) FROM claims)*100,2) AS Claim_Percentage
FROM claims 
GROUP BY Status
'''
cursor.execute(query)
results=cursor.fetchall()

for Claim_ID_, Claim_Count, Claim_Percentage in results:
    print(f"{Claim_ID_}     {Claim_Count}    {Claim_Percentage}  ")
# Out:
# Pending     975    32.50
# Cancelled     1008    33.60
# Completed     1017    33.90

# %% [markdown]
#                 18. Providers with no claims

# %%
query=''' 
SELECT 
    p.Provider_ID,
    p.Name AS Provider_Name
FROM providers p
WHERE NOT EXISTS (
        SELECT 1
        FROM foodlistings f
        JOIN claims c ON f.Food_ID=c.Food_ID
        WHERE f.Provider_ID=p.provider_ID

);

'''
cursor.execute(query)
results=cursor.fetchall()

print("Providers with No Food Claims:")
print("-" * 40)
for provider_id, provider_name in results:
    print(f"Provider ID: {provider_id:<10} | Provider Name: {provider_name}")
# Out:
# Providers with No Food Claims:
# ----------------------------------------
# Provider ID: 3          | Provider Name: Miller-Black
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 6          | Provider Name: Lawson-Walters
# Provider ID: 8          | Provider Name: Curtis-Lewis
# Provider ID: 10         | Provider Name: Hall, Nguyen and Martinez
# Provider ID: 11         | Provider Name: Flores, Jackson and Ford
# Provider ID: 12         | Provider Name: Miller Ltd
# Provider ID: 13         | Provider Name: Parker, Flores and Jennings
# Provider ID: 14         | Provider Name: Nguyen-Tran
# Provider ID: 15         | Provider Name: Valdez-Diaz
# Provider ID: 18         | Provider Name: Edwards-Turner
# Provider ID: 19         | Provider Name: Davis Ltd
# Provider ID: 21         | Provider Name: Cross Group
# Provider ID: 23         | Provider Name: Johnson Ltd
# Provider ID: 25         | Provider Name: Gutierrez-Palmer
# Provider ID: 27         | Provider Name: Lester Inc
# Provider ID: 28         | Provider Name: Wright Ltd
# Provider ID: 30         | Provider Name: Rodriguez PLC
# Provider ID: 32         | Provider Name: Lawrence PLC
# Provider ID: 33         | Provider Name: Miranda, Wilcox and Short
# Provider ID:
# Provider ID: 939        | Provider Name: Reyes and Sons
# Provider ID: 940        | Provider Name: Bradley-Martin
# Provider ID: 941        | Provider Name: George Group
# Provider ID: 942        | Provider Name: Miller LLC
# Provider ID: 943        | Provider Name: York-Ferguson
# Provider ID: 944        | Provider Name: Miller-Bennett
# Provider ID: 945        | Provider Name: Young-Wu
# Provider ID: 947        | Provider Name: Melton, Olson and Foster
# Provider ID: 949        | Provider Name: Jackson, Howe and Gentry
# Provider ID: 950        | Provider Name: Robinson-Gibson
# Provider ID: 953        | Provider Name: Obrien-Zhang
# Provider ID: 954        | Provider Name: Herrera LLC
# Provider ID: 955        | Provider Name: Williams PLC
# Provider ID: 956        | Provider Name: Haynes, Barnett and Wiley
# Provider ID: 957        | Provider Name: Rice and Sons
# Provider ID: 960        | Provider Name: Jackson, Shelton and Mayer
# Provider ID: 961        | Provider Name: Davis, Sanchez and Mendez
# Provider ID: 964        | Provider Name: Graham and Sons
# Provider ID: 966        | Provider Name: Rivers, Pena and Davies
# Provider ID: 969        | Provider Name: Hayden PLC
# Provider ID: 971        | Provider Name: Scott, Davis and Mcbride
# Provider ID: 972        | Provider Name: Hurst, Lee and Sims
# Provider ID: 974        | Provider Name: Jackson LLC
# Provider ID: 975        | Provider Name: Lowe Ltd
# Provider ID: 977        | Provider Name: Anderson and Sons
# Provider ID: 978        | Provider Name: Lewis-Anderson
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 988        | Provider Name: Morris, Serrano and Roberson
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 991        | Provider Name: Spencer LLC
# Provider ID: 992        | Provider Name: Miller-Sanders
# Provider ID: 994        | Provider Name: Porter, Hernandez and Pace
# Provider ID: 996        | Provider Name: Vasquez, Ruiz and Flowers
# Provider ID: 997        | Provider Name: Garza-Williams
# Provider ID: 1000       | Provider Name: Jenkins-Brooks

# %%
query = '''
SELECT 
    p.Provider_ID,
    p.Name AS Provider_Name
FROM 
    providers p
LEFT JOIN 
    foodlistings f ON p.Provider_ID = f.Provider_ID
LEFT JOIN 
    claims c ON f.Food_ID = c.Food_ID
WHERE 
    c.Claim_ID IS NULL;
'''

# Execute the query
cursor.execute(query)

# Fetch all results
results = cursor.fetchall()

# Print results
print("Providers with No Food Claims:")
print("-" * 40)
for provider_id, provider_name in results:
    print(f"Provider ID: {provider_id:<10} | Provider Name: {provider_name}")
# Out:
# Providers with No Food Claims:
# ----------------------------------------
# Provider ID: 2          | Provider Name: Nielsen, Johnson and Fuller
# Provider ID: 2          | Provider Name: Nielsen, Johnson and Fuller
# Provider ID: 2          | Provider Name: Nielsen, Johnson and Fuller
# Provider ID: 2          | Provider Name: Nielsen, Johnson and Fuller
# Provider ID: 2          | Provider Name: Nielsen, Johnson and Fuller
# Provider ID: 2          | Provider Name: Nielsen, Johnson and Fuller
# Provider ID: 2          | Provider Name: Nielsen, Johnson and Fuller
# Provider ID: 2          | Provider Name: Nielsen, Johnson and Fuller
# Provider ID: 2          | Provider Name: Nielsen, Johnson and Fuller
# Provider ID: 2          | Provider Name: Nielsen, Johnson and Fuller
# Provider ID: 2          | Provider Name: Nielsen, Johnson and Fuller
# Provider ID: 3          | Provider Name: Miller-Black
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 5          | Provider Name: Coleman-Farley
# Provider ID: 6          | Provider Name: Lawson-Walters
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 7          | Provider Name: Ortiz-Lee
# Provider ID: 8          | Provider Name: Curtis-Lewis
# Provider ID: 10         | Provider Name: Hall, Nguyen and Martinez
# Provider ID: 10         | Provider Name: Hall, Nguyen and Martinez
# Provider ID: 10         | Provider Name: Hall, Nguyen and Martinez
# Provider ID: 10         | Provider Name: Hall, Nguyen and Martinez
# Provider ID: 10         | Provider Name: Hall, Nguyen and Martinez
# Provider ID: 10         | Provider Name: Hall, Nguyen and Martinez
# Provider ID: 10         | Provider Name: Hall, Nguyen and Martinez
# Provider ID: 10         | Provider Name: Hall, Nguyen and Martinez
# Provider ID: 10         | Provider Name: Hall, Nguyen and Martinez
# Provider ID: 10         | Provider Name: Hall, Nguyen and Martinez
# Provider ID: 10         | Provider Name: Hall, Nguyen and Martinez
# Provider ID: 11         | Provider Name: Flores, Jackson and Ford
# Provider ID: 11         | Provider Name: Flores, Jackson and Ford
# Provider ID: 11         | Provider Name: Flores, Jackson and Ford
# Provider ID: 11         | Provider Name: Flores, Jackson and Ford
# Provider ID: 11         | Provider Name: Flores, Jackson and Ford
# Provider ID: 11         | Provider Name: Flores, Jackson and Ford
# Provider ID: 11         | Provider Name: Flores, Jackson and Ford
# Provider ID: 11         | Provider Name: Flores, Jackson and Ford
# Provider ID: 11         | Provider Name: Flores, Jackson and Ford
# Provider ID: 11         | Provider Name: Flores, Jackson and Ford
# Provider ID: 11         | Provider Name: Flores, Jackson and Ford
# Provider ID: 12         | Provider Name: Miller Ltd
# Provider ID: 13         | Provider Name: Parker, Flores and Jennings
# Provider ID: 14         | Provider Name: Nguyen-Tran
# Provider ID: 14         | Provider Name: Nguyen-Tran
# Provider ID: 14         | Provider Name: Nguyen-Tran
# Provider ID: 14         | Provider Name: Nguyen-Tran
# Provider ID: 14         | Provider Name: Nguyen-Tran
# Provider ID: 14         | Provider Name: Nguyen-Tran
# Provider ID: 14         | Provider Name: Nguyen-Tran
# Provider ID: 14         | Provider Name: Nguyen-Tran
# Provider ID: 14         | Provider Name: Nguyen-Tran
# Provider ID: 14         | Provider Name: Nguyen-Tran
# Provider ID:
C
# Provider ID: 38         | Provider Name: Lawrence LLC
# Provider ID: 38         | Provider Name: Lawrence LLC
# Provider ID: 38         | Provider Name: Lawrence LLC
# Provider ID: 38         | Provider Name: Lawrence LLC
# Provider ID: 38         | Provider Name: Lawrence LLC
# Provider ID: 38         | Provider Name: Lawrence LLC
# Provider ID: 38         | Provider Name: Lawrence LLC
# Provider ID: 38         | Provider Name: Lawrence LLC
# Provider ID: 38         | Provider Name: Lawrence LLC
# Provider ID: 38         | Provider Name: Lawrence LLC
# Provider ID: 40         | Provider Name: Robinson PLC
# Provider ID: 40         | Provider Name: Robinson PLC
# Provider ID: 40         | Provider Name: Robinson PLC
# Provider ID: 40         | Provider Name: Robinson PLC
# Provider ID: 40         | Provider Name: Robinson PLC
# Provider ID: 40         | Provider Name: Robinson PLC
# Provider ID: 40         | Provider Name: Robinson PLC
# Provider ID: 40         | Provider Name: Robinson PLC
# Provider ID: 40         | Provider Name: Robinson PLC
# Provider ID: 40         | Provider Name: Robinson PLC
# Provider ID: 40         | Provider Name: Robinson PLC
# Provider ID: 41         | Provider Name: Kelly-Ware
# Provider ID: 41         | Provider Name: Kelly-Ware
# Provider ID: 41         | Provider Name: Kelly-Ware
# Provider ID: 41         | Provider Name: Kelly-Ware
# Provider ID: 41         | Provider Name: Kelly-Ware
# Provider ID: 41         | Provider Name: Kelly-Ware
# Provider ID: 41         | Provider Name: Kelly-Ware
# Provider ID: 41         | Provider Name: Kelly-Ware
# Provider ID: 41         | Provider Name: Kelly-Ware
# Provider ID: 41         | Provider Name: Kelly-Ware
# Provider ID: 41         | Provider Name: Kelly-Ware
# Provider ID: 43         | Provider Name: Martinez, Johnson and Torres
# Provider ID: 43         | Provider Name: Martinez, Johnson and Torres
# Provider ID: 43         | Provider Name: Martinez, Johnson and Torres
# Provider ID: 43         | Provider Name: Martinez, Johnson and Torres
# Provider ID: 43         | Provider Name: Martinez, Johnson and Torres
# Provider ID: 43         | Provider Name: Martinez, Johnson and Torres
# Provider ID: 43         | Provider Name: Martinez, Johnson and Torres
# Provider ID: 43         | Provider Name: Martinez, Johnson and Torres
# Provider ID: 43         | Provider Name: Martinez, Johnson and Torres
# Provider ID: 43         | Provider Name: Martinez, Johnson and Torres
# Provider ID: 43         | Provider Name: Martinez, Johnson and Torres
# Provider ID: 44         | Provider Name: Torres-Perez
# Provider ID: 46         | Provider Name: Fisher, Hernandez and Webster
# Provider ID: 46         | Provider Name: Fisher, Hernandez and Webster
# Provider ID: 46         | Provider Name: Fisher, Hernandez and Webster
# Provider ID: 46         | Provider Name: Fisher, Hernandez and Webster
# Provider ID: 46         | Provider Name: Fisher, Hernandez and Webster
# Provider ID: 46         | Provider Name: Fisher, Hernandez and Webster
# Provider ID: 46         | Provider Name: Fisher, Hernandez and Webster
# Provider ID: 46         | Provider Name: Fisher, Hernandez and Webster
# Provider ID: 46         | Provider Name: Fisher, Hernandez and Webster
# Provider ID: 46         | Provider Name: Fisher, Hernandez and Webster
# Provider ID: 46         | Provider Name: Fisher, Hernandez and Webster
# Provider ID: 47         | Provider Name: Wong-Reese
# Provider ID: 47         | Provider Name: Wong-Reese
# Provider ID: 47         | Provider Name: Wong-Reese
# Provider ID: 47         | Provider Name: Wong-Reese
# Provider ID: 47         | Provider Name: Wong-Reese
# Provider ID: 47         | Provider Name: Wong-Reese
# Provider ID: 47         | Provider Name: Wong-Reese
# Provider ID: 47         | Provider Name: Wong-Reese
# Provider ID: 47         | Provider Name: Wong-Reese
# Provider ID: 47         | Provider Name: Wong-Reese
# Provider ID: 47         | Provider Name: Wong-Reese
# Provider ID: 51         | Provider Name: Shaw Inc
# Provider ID: 53         | Provider Name: Wolfe and Sons
# Provider ID: 57         | Provider Name: Cook Group
# Provider ID: 57         | Provider Name: Cook Group
# Provider ID: 57         | Provider Name: Cook Group
# Provider ID: 57         | Provider Name: Cook Group
# Provider ID: 57         | Provider Name: Cook Group
# Provider ID: 57         | Provider Name: Cook Group
# Provider ID: 57         | Provider Name: Cook Group
# Provider ID: 57         | Provider Name: Cook Group
# Provider ID: 57         | Provider Name: Cook Group
# Provider ID: 57         | Provider Name: Cook Group
# Provider ID: 57         | Provider Name: Cook Group
# Provider ID: 61         | Provider Name: Arnold, Russo and Foster
# Provider ID: 62         | Provider Name: Mitchell, Campbell and Jones
# Provider ID: 62         | Provider Name: Mitchell, Campbell and Jones
# Provider ID: 62         | Provider Name: Mitchell, Campbell and Jones
# Provider ID: 62         | Provider Name: Mitchell, Campbell and Jones
# Provider ID: 62         | Provider Name: Mitchell, Campbell and Jones
# Provider ID: 62         | Provider Name: Mitchell, Campbell and Jones
# Provider ID: 62         | Provider Name: Mitchell, Campbell and Jones
# Provider ID: 62         | Provider Name: Mitchell, Campbell and Jones
# Provider ID: 62         | Provider Name: Mitchell, Campbell and Jones
# Provider ID: 62         | Provider Name: Mitchell, Campbell and Jones
# Provider ID: 62         | Provider Name: Mitchell, Campbell and Jones
# Provider ID: 64         | Provider Name: Mullen LLC
# Provider ID:
# Provider ID: 970        | Provider Name: Lewis, Preston and Price
# Provider ID: 970        | Provider Name: Lewis, Preston and Price
# Provider ID: 970        | Provider Name: Lewis, Preston and Price
# Provider ID: 970        | Provider Name: Lewis, Preston and Price
# Provider ID: 971        | Provider Name: Scott, Davis and Mcbride
# Provider ID: 972        | Provider Name: Hurst, Lee and Sims
# Provider ID: 974        | Provider Name: Jackson LLC
# Provider ID: 975        | Provider Name: Lowe Ltd
# Provider ID: 977        | Provider Name: Anderson and Sons
# Provider ID: 977        | Provider Name: Anderson and Sons
# Provider ID: 977        | Provider Name: Anderson and Sons
# Provider ID: 977        | Provider Name: Anderson and Sons
# Provider ID: 977        | Provider Name: Anderson and Sons
# Provider ID: 977        | Provider Name: Anderson and Sons
# Provider ID: 977        | Provider Name: Anderson and Sons
# Provider ID: 977        | Provider Name: Anderson and Sons
# Provider ID: 977        | Provider Name: Anderson and Sons
# Provider ID: 977        | Provider Name: Anderson and Sons
# Provider ID: 977        | Provider Name: Anderson and Sons
# Provider ID: 978        | Provider Name: Lewis-Anderson
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 979        | Provider Name: Gray PLC
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 986        | Provider Name: Wilson, Harris and Mayo
# Provider ID: 988        | Provider Name: Morris, Serrano and Roberson
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 989        | Provider Name: Williams-Aguirre
# Provider ID: 991        | Provider Name: Spencer LLC
# Provider ID: 992        | Provider Name: Miller-Sanders
# Provider ID: 994        | Provider Name: Porter, Hernandez and Pace
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 995        | Provider Name: Moore Group
# Provider ID: 996        | Provider Name: Vasquez, Ruiz and Flowers
# Provider ID: 997        | Provider Name: Garza-Williams
# Provider ID: 997        | Provider Name: Garza-Williams
# Provider ID: 997        | Provider Name: Garza-Williams
# Provider ID: 997        | Provider Name: Garza-Williams
# Provider ID: 997        | Provider Name: Garza-Williams
# Provider ID: 997        | Provider Name: Garza-Williams
# Provider ID: 997        | Provider Name: Garza-Williams
# Provider ID: 997        | Provider Name: Garza-Williams
# Provider ID: 997        | Provider Name: Garza-Williams
# Provider ID: 997        | Provider Name: Garza-Williams
# Provider ID: 997        | Provider Name: Garza-Williams
# Provider ID: 1000       | Provider Name: Jenkins-Brooks
# Provider ID: 1000       | Provider Name: Jenkins-Brooks
# Provider ID: 1000       | Provider Name: Jenkins-Brooks
# Provider ID: 1000       | Provider Name: Jenkins-Brooks
# Provider ID: 1000       | Provider Name: Jenkins-Brooks
# Provider ID: 1000       | Provider Name: Jenkins-Brooks
# Provider ID: 1000       | Provider Name: Jenkins-Brooks
# Provider ID: 1000       | Provider Name: Jenkins-Brooks
# Provider ID: 1000       | Provider Name: Jenkins-Brooks
# Provider ID: 1000       | Provider Name: Jenkins-Brooks
# Provider ID: 1000       | Provider Name: Jenkins-Brooks

# %% [markdown]
#                 19. Total claims and quantity per Meal type

# %%
query=''' 
SELECT 
        f.Meal_Type,
        COUNT(c.Claim_ID) AS Total_Claims,
        SUM(f.Quantity) AS Total_Quantity
FROM
    claims c
JOIN foodlistings f ON c.Food_ID=f.Food_ID
GROUP BY f.Meal_Type, f.Quantity
ORDER BY Total_Quantity



'''
cursor.execute(query)

results = cursor.fetchall()

print("Total claims and quantity per meal type:")
print("-" * 40)
for meal_type_, Total_Claims, Total_Quantity in results:
    print(f"Meal Type: {meal_type_:<10} | Quantity: {Total_Quantity:<12}    |  Claims: {Total_Claims}")
# Out:
# Total claims and quantity per meal type:
# ----------------------------------------
# Meal Type: Snacks     | Quantity: 66              |  Claims: 66
# Meal Type: Lunch      | Quantity: 66              |  Claims: 66
# Meal Type: Dinner     | Quantity: 132             |  Claims: 132
# Meal Type: Lunch      | Quantity: 198             |  Claims: 99
# Meal Type: Snacks     | Quantity: 264             |  Claims: 33
# Meal Type: Snacks     | Quantity: 297             |  Claims: 99
# Meal Type: Snacks     | Quantity: 330             |  Claims: 165
# Meal Type: Dinner     | Quantity: 330             |  Claims: 165
# Meal Type: Snacks     | Quantity: 330             |  Claims: 66
# Meal Type: Snacks     | Quantity: 396             |  Claims: 99
# Meal Type: Lunch      | Quantity: 396             |  Claims: 99
#                 21. Most Common Type of Receiver

# %%
query=''' 
SELECT 
    r.Type as Receiver_type,
    COUNT(*) AS Receiver_type_count
FROM receivers r
GROUP BY r.Type
ORDER BY Receiver_type_count DESC
LIMIT 1;
'''
cursor.execute(query)

results = cursor.fetchall()

print("Most Common Type of Receiver")
print("-" * 40)
for Receiver_type, Receiver_type_count in results:
    print(f"Receiver Type: {Receiver_type:<10} | Count: {Receiver_type_count:<12}  ")
# Out:
# Most Common Type of Receiver
# ----------------------------------------
# Receiver Type: NGO        | Count: 3836

# %% [markdown]
#                 22. Receiver type by count

# %%
query=''' 
SELECT 
    r.Type AS Receiver_type,
    COUNT(*) AS Receiver_Type_Count
FROM receivers r
GROUP BY r.Type
ORDER BY Receiver_Type_Count;


'''
cursor.execute(query)

results = cursor.fetchall()

print("Receiver type of count")
print("-" * 40)
for Receiver_type, Receiver_Type_Count in results:
    print(f"Receiver Type: {Receiver_type:<10} | Count: {Receiver_Type_Count:<12}  ")
# Out:
# Receiver type of count
# ----------------------------------------
# Receiver Type: Individual | Count: 3038
# Receiver Type: Shelter    | Count: 3444
# Receiver Type: Charity    | Count: 3682
# Receiver Type: NGO        | Count: 3836

# %% [markdown]
#                 23. Receiver count by city

# %%
query= ''' 
SELECT  
    City AS Receiver_City,
    COUNT(*) AS Receiver_city_count
FROM receivers
GROUP BY City
ORDER BY Receiver_city_count


'''

cursor.execute(query)

results = cursor.fetchall()

print("Receiver cities by Count")
print("-" * 40)
for Receiver_city, Receiver_city_count in results:
    print(f"Receiver Type: {Receiver_city:<30} | Count: {Receiver_city_count:<12}  ")
# Out:
# Receiver cities by Count
# ----------------------------------------
# Receiver Type: Port Carlburgh                 | Count: 14
# Receiver Type: Lewisburgh                     | Count: 14
# Receiver Type: South Randalltown              | Count: 14
# Receiver Type: South Shaneville               | Count: 14
# Receiver Type: Bakerport                      | Count: 14
# Receiver Type: East Sharimouth                | Count: 14
# Receiver Type: South Edwinborough             | Count: 14
# Receiver Type: Benjaminburgh                  | Count: 14
# Receiver Type: West Robert                    | Count: 14
# Receiver Type: Wrightland                     | Count: 14
# Receiver Type: South Gregorymouth             | Count: 14
# Receiver Type: Katherineside                  | Count: 14
# Receiver Type: Lake Matthewstad               | Count: 14
# Receiver Type: Burkeside                      | Count: 14
# Receiver Type: Port Ronald                    | Count: 14
# Receiver Type: Port Tara                      | Count: 14
# Receiver Type: Silvaport                      | Count: 14
# Receiver Type: Moranhaven                     | Count: 14
# Receiver Type: North Cynthiaberg              | Count: 14
# Receiver Type: Sandrahaven                    | Count: 14
# Receiver Type: Jonesside                      | Count: 14
# Receiver Type: Lake Nicole                    | Count: 14
# Receiver Type: Aliciabury                     | Count: 14
# Receiver Type: Monicafort                     | Count: 14
# Receiver Type: Lake Elizabeth                 | Count: 14
# Receiver Type: Port Matthewmouth              | Count: 14
# Receiver Type: Susanfurt                      | Count: 14
# Receiver Type: Courtneyfurt                   | Count: 14
# Receiver Type: Lake Kendra                    | Count: 14
# Receiver Type: North Heather                  | Count: 14
# Receiver Type: Taylorfort                     | Count: 14
# Receiver Type: Walshfort                      | Count: 14
# Receiver Type: North Robert                   | Count: 14
# Receiver Type: South Rachaelhaven             | Count: 14
# Receiver Type: Olsonville                     | Count: 14
# Receiver Type: West Erik                      | Count: 14
# Receiver Type: Josephview                     | Count: 14
# Receiver Type: West Carrie                    | Count: 14
# Receiver Type: Port Kellyburgh                | Count: 14
# Receiver Type: Port Dawntown                  | Count: 14
# Receiver Type: Amberfort                      | Count: 14
# Receiver Type: Davisborough                   | Count: 14
# Receiver Type: South Laurachester             | Count: 14
# Receiver Type: East Teresahaven               | Count: 14
# Receiver Type: East Saraport                  | Count: 14
# Receiver Type: South Tonyaborough             | Count: 14
# Receiver Type: North Sarah                    | Count: 14
# Receiver Type: Port Johnchester               | Count: 14
# Receiver Type: Hornemouth                     | Count: 14
# Receiver Type: Tomburgh                       | Count: 14
# Receiver Type: Higginsmouth                   | Count: 14
# Receiver Type: Larastad                       | Count: 14
# Receiver Type: Jasonshire                     | Count: 14
# Receiver Type: New Mary                       | Count: 14
# Receiver Type: Michaelton                     | Count: 14
# Receiver Type: Phillipborough                 | Count: 14
# Receiver Type: South Kathleenbury             | Count: 14
# Receiver Type: North Catherinefurt            | Count: 14
# Receiver Type: East William                   | Count: 14
# Receiver Type: North Darinshire               | Count: 14
# Receiver Type: Port Belinda                   | Count: 14
# Receiver Type: West Jaclyn                    | Count: 14
# Receiver Type: Strongshire                    | Count: 14
# Receiver Type: Edwardburgh                    | Count: 14
# Receiver Type: East Dylan                     | Count: 14
# Receiver Type: Gregoryville                   | Count: 14
# Receiver Type: New Gloriaburgh                | Count: 14
# Receiver Type: West Angelatown                | Count: 14
# Receiver Type: Christineton                   | Count: 14
# Receiver Type: Laurafurt                      | Count: 14
# Receiver Type: Manningtown                    | Count: 14
# Receiver Type: North Jenniferside             | Count: 14
# Receiver Type: North David                    | Count: 14
# Receiver Type: Marshallton                    | Count: 14
# Receiver Type: Angelaville                    | Count: 14
# Receiver Type: Knightburgh                    | Count: 14
# Receiver Type: Port Gregoryport               | Count: 14
# Receiver Type: Evansside                      | Count: 14
# Receiver Type: Davidview                      | Count: 14
# Receiver Type: East Kelli                     | Count: 14
# Receiver Type: Lake John                      | Count: 14
# Receiver Type: West Ronaldland                | Count: 14
# Receiver Type: Robinsonside                   | Count: 14
# Receiver Type: Garrettborough                 | Count: 14
# Receiver Type: Alexatown                      | Count: 14
# Receiver Type: New Jessica                    | Count: 14
# Receiver Type: Laurafort                      | Count: 14
# Receiver Type: Carterside                     | Count: 14
# Receiver Type: South Veronicaburgh            | Count: 14
# Receiver Type: Henryhaven                     | Count: 14
# Receiver Type: Russellville                   | Count: 14
# Receiver Type: Robertaborough                 | Count: 14
# Receiver Type: Hollytown                      | Count: 14
# Receiver Type: North Matthewhaven             | Count: 14
# Receiver Type: West Justin                    | Count: 14
# Receiver Type: North Joshuafort               | Count: 14
# Receiver Type: North Pamela                   | Count: 14
# Receiver Type: Lake Rebecca                   | Count: 14
# Receiver Type: Port Elizabethton              | Count: 14
# Receiver Type: East Josephstad                | Count: 14
# Receiver Type: Theresamouth                   | Count: 14
# Receiver Type: Lake Michaelton                | Count: 14
# Receiver Type: West Johnny                    | Count: 14
# Receiver Type: Michaeltown                    | Count: 14
# Receiver Type: Georgeborough                  | Count: 14
# Receiver Type: Meganton                       | Count: 14
# Receiver Type: Scottmouth                     | Count: 14
# Receiver Type: Port Teresa                    | Count: 14
# Receiver Type: East Heatherborough            | Count: 14
# Receiver Type: South Franciscoport            | Count: 14
# Receiver Type: Deanview                       | Count: 14
# Receiver Type: Kennethberg                    | Count: 14
# Receiver Type: Ayalamouth                     | Count: 14
# Receiver Type: Port Patriciachester           | Count: 14
# Receiver Type: South Alexandraport            | Count: 14
# Receiver Type: Meghanfort                     | Count: 14
# Receiver Type: Campbellchester                | Count: 14
# Receiver Type: North Roger                    | Count: 14
# Receiver Type: New Benjamin                   | Count: 14
# Receiver Type: Drakeburgh                     | Count: 14
# Receiver Type: Marieview                      | Count: 14
# Receiver Type: Jeffhaven                      | Count: 14
# Receiver Type: South Jasonberg                | Count: 14
# Receiver Type: Marcusberg                     | Count: 14
# Receiver Type: Huntermouth                    | Count: 14
# Receiver Type: New Elaine                     | Count: 14
# Receiver Type: Bakerfort                      | Count: 14
# Receiver Type: Phillipsbury                   | Count: 14
# Receiver Type: Dawnview                       | Count: 14
# Receiver Type: Wilsonfort                     | Count: 14
# Receiver Type: Nancyshire                     | Count: 14
# Receiver Type: North Paul                     | Count: 14
# Receiver Type: Tanyachester                   | Count: 14
# Receiver Type: Joshuamouth                    | Count: 14
# Receiver Type: New Shannonbury                | Count: 14
# Receiver Type: North Amandafort               | Count: 14
# Receiver Type: Danielfort                     | Count: 14
# Receiver Type: New Aimeemouth                 | Count: 14
# Receiver Type: Caseyland                      | Count: 14
# Receiver Type: Williamtown                    | Count: 14
# Receiver Type: Lake Victoriaport              | Count: 14
# Receiver Type: Patriciaton                    | Count: 14
# Receiver Type: Jacobsmouth                    | Count: 14
# Receiver Type: Charleston                     | Count: 14
# Receiver Type: South Ashley                   | Count: 14
# Receiver Type: Lisaton                        | Count: 14
# Receiver Type: South Jill                     | Count: 14
# Receiver Type: Mcclurestad                    | Count: 14
# Receiver Type: Amandaville                    | Count: 14
# Receiver Type: Daleshire                      | Count: 14
# Receiver Type: Heatherfurt                    | Count: 14
# Receiver Type: East Sarahtown                 | Count: 14
# Receiver Type: Ginamouth                      | Count: 14
# Receiver Type: West Shawn                     | Count: 14
# Receiver Type: East Timhaven                  | Count: 14
# Receiver Type: Nguyenfurt                     | Count: 14
# Receiver Type: Port Erica                     | Count: 14
# Receiver Type: Joanchester                    | Count: 14
# Receiver Type: Thomaston                      | Count: 14
# Receiver Type: West Courtneyport              | Count: 14
# Receiver Type: Smithstad                      | Count: 14
# Receiver Type: New Tiffany                    | Count: 14
# Receiver Type: Nicoleport                     | Count: 14
# Receiver Type: Robertsonchester               | Count: 14
# Receiver Type: Port Emilymouth                | Count: 14
# Receiver Type: West Krystalview               | Count: 14
# Receiver Type: Peterhaven                     | Count: 14
# Receiver Type: Seanside                       | Count: 14
# Receiver Type: Thomasland                     | Count: 14
# Receiver Type: Port Melissa                   | Count: 14
# Receiver Type: Lake Amanda                    | Count: 14
# Receiver Type: Heathertown                    | Count: 14
# Receiver Type: Lake Erica                     | Count: 14
# Receiver Type: Angelicatown                   | Count: 14
# Receiver Type: Maxberg                        | Count: 14
# Receiver Type: North Shelby                   | Count: 14
# Receiver Type: New Seanburgh                  | Count: 14
# Receiver Type: Toddborough                    | Count: 14
# Receiver Type: Figueroaport                   | Count: 14
# Receiver Type: Shawmouth                      | Count: 14
# Receiver Type: New Jason                      | Count: 14
# Receiver Type: Port Dustin                    | Count: 14
# Receiver Type: East Tinamouth                 | Count: 14
# Receiver Type: East Teresamouth               | Count: 14
# Receiver Type: East Sharon                    | Count: 14
# Receiver Type: East Jillian                   | Count: 14
# Receiver Type: Corybury                       | Count: 14
# Receiver Type: North Mario                    | Count: 14
# Receiver Type: North Lindachester             | Count: 14
# Receiver Type: West Casey                     | Count: 14
# Receiver Type: Ramseystad                     | Count: 14
# Receiver Type: South Kendraville              | Count: 14
# Receiver Type: Andrewmouth                    | Count: 14
# Receiver Type: Steveberg                      | Count: 14
# Receiver Type: South Anna                     | Count: 14
# Receiver Type: Baileyville                    | Count: 14
# Receiver Type: New Roseville                  | Count: 14
# Receiver Type: Port Stephen                   | Count: 14
# Receiver Type: West Amybury                   | Count: 14
# Receiver Type: New Daniel                     | Count: 14
# Receiver Type: Lake Austinmouth               | Count: 14
# Receiver Type: Dantown                        | Count: 14
# Receiver Type: Robinsonland                   | Count: 14
# Receiver Type: West Aaronport                 | Count: 14
# Receiver Type: Hallside                       | Count: 14
# Receiver Type: East Jacob                     | Count: 14
# Receiver Type: West Jessica                   | Count: 14
# Receiver Type: Fergusonton                    | Count: 14
# Receiver Type: Port Maria                     | Count: 14
# Receiver Type: Singletonview                  | Count: 14
# Receiver Type: Bushview                       | Count: 14
# Receiver Type: Poolestad                      | Count: 14
# Receiver Type: Port Brianville                | Count: 14
# Receiver Type: Davidshire                     | Count: 14
# Receiver Type: Port Ericmouth                 | Count: 14
# Receiver Type: Lake Julia                     | Count: 14
# Receiver Type: Rogerburgh                     | Count: 14
# Receiver Type: West Josephshire               | Count: 14
# Receiver Type: Davisburgh                     | Count: 14
# Receiver Type: North Kimberlyport             | Count: 14
# Receiver Type: Edwardsside                    | Count: 14
# Receiver Type: Wilsonfurt                     | Count: 14
# Receiver Type: Garciaview                     | Count: 14
# Receiver Type: West Vickie                    | Count: 14
# Receiver Type: Carolhaven                     | Count: 14
# Receiver Type: New Craig                      | Count: 14
# Receiver Type: Lake Darrellburgh              | Count: 14
# Receiver Type: Aaronshire                     | Count: 14
# Receiver Type: New Abigail                    | Count: 14
# Receiver Type: Lake Kelli                     | Count: 14
# Receiver Type: Jenniferberg                   | Count: 14
# Receiver Type: Martinland                     | Count: 14
# Receiver Type: New Julian                     | Count: 14
# Receiver Type: West Christiantown             | Count: 14
# Receiver Type: New Tina                       | Count: 14
# Receiver Type: Christopherland                | Count: 14
# Receiver Type: South Amy                      | Count: 14
# Receiver Type: Barnesport                     | Count: 14
# Receiver Type: Lake Jessicaborough            | Count: 14
# Receiver Type: East Moniquemouth              | Count: 14
# Receiver Type: East John                      | Count: 14
# Receiver Type: West Johnmouth                 | Count: 14
# Receiver Type: West Kelly                     | Count: 14
# Receiver Type: Murrayview                     | Count: 14
# Receiver Type: Bauerton                       | Count: 14
# Receiver Type: Dylanton                       | Count: 14
# Receiver Type: Monicaton                      | Count: 14
# Receiver Type: East Ashleyshire               | Count: 14
# Receiver Type: Brianchester                   | Count: 14
# Receiver Type: Autumnbury                     | Count: 14
# Receiver Type: East Williamborough            | Count: 14
# Receiver Type: Brandonside                    | Count: 14
# Receiver Type: West Christopher               | Count: 14
# Receiver Type: Port Jessica                   | Count: 14
# Receiver Type: Port Samanthamouth             | Count: 14
# Receiver Type: Lake Christychester            | Count: 14
# Receiver Type: Lake Stephenport               | Count: 14
# Receiver Type: Isaiahtown                     | Count: 14
# Receiver Type: Dustinfurt                     | Count: 14
# Receiver Type: Stephaniechester               | Count: 14
# Receiver Type: Castilloland                   | Count: 14
# Receiver Type: Burnettton                     | Count: 14
# Receiver Type: Susanview                      | Count: 14
# Receiver Type: Lake Tina                      | Count: 14
# Receiver Type: Hannahside                     | Count: 14
# Receiver Type: North Josephland               | Count: 14
# Receiver Type: Shermantown                    | Count: 14
# Receiver Type: East Bryan                     | Count: 14
# Receiver Type: Jamesstad                      | Count: 14
# Receiver Type: East Dale                      | Count: 14
# Receiver Type: Lake Michael                   | Count: 14
# Receiver Type: Aguilarstad                    | Count: 14
# Receiver Type: Marksmouth                     | Count: 14
# Receiver Type: Alexanderbury                  | Count: 14
# Receiver Type: North Alexander                | Count: 14
# Receiver Type: Melissaport                    | Count: 14
# Receiver Type: Millerport                     | Count: 14
# Receiver Type: Edwardshaven                   | Count: 14
# Receiver Type: Kellyville                     | Count: 14
# Receiver Type: Calebview                      | Count: 14
# Receiver Type: North Patriciamouth            | Count: 14
# Receiver Type: Cynthiashire                   | Count: 14
# Receiver Type: New Julia                      | Count: 14
# Receiver Type: New Sara                       | Count: 14
# Receiver Type: Geraldchester                  | Count: 14
# Receiver Type: Schaeferfort                   | Count: 14
# Receiver Type: North Kimberlyfort             | Count: 14
# Receiver Type: Haleymouth                     | Count: 14
# Receiver Type: West Aaronberg                 | Count: 14
# Receiver Type: Meganmouth                     | Count: 14
# Receiver Type: Lake Glenview                  | Count: 14
# Receiver Type: Danielborough                  | Count: 14
# Receiver Type: Andersenfort                   | Count: 14
# Receiver Type: North Williamview              | Count: 14
# Receiver Type: South Bethanyport              | Count: 14
# Receiver Type: North Ashleymouth              | Count: 14
# Receiver Type: New Sarahmouth                 | Count: 14
# Receiver Type: Thompsonhaven                  | Count: 14
# Receiver Type: South Amybury                  | Count: 14
# Receiver Type: East Gina                      | Count: 14
# Receiver Type: Melissaview                    | Count: 14
# Receiver Type: New Justinhaven                | Count: 14
# Receiver Type: Edwardfort                     | Count: 14
# Receiver Type: North Bruce                    | Count: 14
# Receiver Type: Reidton                        | Count: 14
# Receiver Type: Hammondfort                    | Count: 14
# Receiver Type: Chaseview                      | Count: 14
# Receiver Type: Lake Melindaside               | Count: 14
# Receiver Type: Victoriastad                   | Count: 14
# Receiver Type: East Lisafurt                  | Count: 14
# Receiver Type: South Michelleshire            | Count: 14
# Receiver Type: Thomasberg                     | Count: 14
# Receiver Type: Gomezmouth                     | Count: 14
# Receiver Type: New William                    | Count: 14
# Receiver Type: Murphyfort                     | Count: 14
# Receiver Type: Melindaview                    | Count: 14
# Receiver Type: Priceborough                   | Count: 14
# Receiver Type: Rushfurt                       | Count: 14
# Receiver Type: East Joseph                    | Count: 14
# Receiver Type: Maryfort                       | Count: 14
# Receiver Type: Angelamouth                    | Count: 14
# Receiver Type: Juliastad                      | Count: 14
# Receiver Type: Lake Lesliemouth               | Count: 14
# Receiver Type: Lake Dillonborough             | Count: 14
# Receiver Type: Swansonport                    | Count: 14
# Receiver Type: West Jeffrey                   | Count: 14
# Receiver Type: West Dan                       | Count: 14
# Receiver Type: North Nicole                   | Count: 14
# Receiver Type: Johnland                       | Count: 14
# Receiver Type: North Jamesfurt                | Count: 14
# Receiver Type: New Corey                      | Count: 14
# Receiver Type: South John                     | Count: 14
# Receiver Type: Jaredport                      | Count: 14
# Receiver Type: West Matthewborough            | Count: 14
# Receiver Type: Duncanchester                  | Count: 14
# Receiver Type: Paulmouth                      | Count: 14
# Receiver Type: Port Dean                      | Count: 14
# Receiver Type: South Barbaraburgh             | Count: 14
# Receiver Type: Port Brandonberg               | Count: 14
# Receiver Type: Port Johnstad                  | Count: 14
# Receiver Type: Lake Stevenburgh               | Count: 14
# Receiver Type: Jamieview                      | Count: 14
# Receiver Type: Leeton                         | Count: 14
# Receiver Type: Lawrencechester                | Count: 14
# Receiver Type: Lake Cory                      | Count: 14
# Receiver Type: Lake Ryan                      | Count: 14
# Receiver Type: Reevestown                     | Count: 14
# Receiver Type: Perezport                      | Count: 14
# Receiver Type: West Tina                      | Count: 14
# Receiver Type: North Michelle                 | Count: 14
# Receiver Type: Kellyfurt                      | Count: 14
# Receiver Type: Tiffanyport                    | Count: 14
# Receiver Type: Lisafurt                       | Count: 14
# Receiver Type: Rachelberg                     | Count: 14
# Receiver Type: Lake Jonathanchester           | Count: 14
# Receiver Type: New Brandonton                 | Count: 14
# Receiver Type: Lake Clinton                   | Count: 14
# Receiver Type: Gordonstad                     | Count: 14
# Receiver Type: West Jorge                     | Count: 14
# Receiver Type: Sarahville                     | Count: 14
# Receiver Type: Sherryhaven                    | Count: 14
# Receiver Type: New Amy                        | Count: 14
# Receiver Type: Bergerport                     | Count: 14
# Receiver Type: Port Carmen                    | Count: 14
# Receiver Type: West Donnaton                  | Count: 14
# Receiver Type: West Randall                   | Count: 14
# Receiver Type: Lake Matthew                   | Count: 14
# Receiver Type: North Manuel                   | Count: 14
# Receiver Type: New Deborahville               | Count: 14
# Receiver Type: New Kevin                      | Count: 14
# Receiver Type: Chambersmouth                  | Count: 14
# Receiver Type: Lake Crystal                   | Count: 14
# Receiver Type: Clarkhaven                     | Count: 14
# Receiver Type: Morganville                    | Count: 14
# Receiver Type: North Abigail                  | Count: 14
# Receiver Type: West Mikayla                   | Count: 14
# Receiver Type: Port Dianemouth                | Count: 14
# Receiver Type: New Natalieland                | Count: 14
# Receiver Type: Lake Laurenburgh               | Count: 14
# Receiver Type: Christinaland                  | Count: 14
# Receiver Type: Rayfurt                        | Count: 14
# Receiver Type: North Holly                    | Count: 14
# Receiver Type: Port Thomasstad                | Count: 14
# Receiver Type: Josephborough                  | Count: 14
# Receiver Type: Jonathanview                   | Count: 14
# Receiver Type: South Tyler                    | Count: 14
# Receiver Type: South Edwardburgh              | Count: 14
# Receiver Type: Lewisfort                      | Count: 14
# Receiver Type: Chadport                       | Count: 14
# Receiver Type: Rosaleschester                 | Count: 14
# Receiver Type: Lake Steven                    | Count: 14
# Receiver Type: Lake Karen                     | Count: 14
# Receiver Type: Russellburgh                   | Count: 14
# Receiver Type: Pagemouth                      | Count: 14
# Receiver Type: East Douglas                   | Count: 14
# Receiver Type: East Melissaport               | Count: 14
# Receiver Type: Lake Kyleside                  | Count: 14
# Receiver Type: South Connorview               | Count: 14
# Receiver Type: Martinezside                   | Count: 14
# Receiver Type: Robertsport                    | Count: 14
# Receiver Type: West Rogerview                 | Count: 14
# Receiver Type: Lake Joshuaville               | Count: 14
# Receiver Type: North Margarethaven            | Count: 14
# Receiver Type: Troyshire                      | Count: 14
# Receiver Type: West Cherylland                | Count: 14
# Receiver Type: Port Sara                      | Count: 14
# Receiver Type: Port Michaelmouth              | Count: 14
# Receiver Type: Coreymouth                     | Count: 14
# Receiver Type: North Kathryn                  | Count: 14
# Receiver Type: Port Deborahbury               | Count: 14
# Receiver Type: Mikemouth                      | Count: 14
# Receiver Type: New Timothymouth               | Count: 14
# Receiver Type: Port Jenniferborough           | Count: 14
# Receiver Type: New Rebecca                    | Count: 14
# Receiver Type: Hollyside                      | Count: 14
# Receiver Type: Port Judith                    | Count: 14
# Receiver Type: Davidport                      | Count: 14
# Receiver Type: Cruzborough                    | Count: 14
# Receiver Type: Port Deborah                   | Count: 14
# Receiver Type: Lake Christina                 | Count: 14
# Receiver Type: Sandratown                     | Count: 14
# Receiver Type: East Andrewhaven               | Count: 14
# Receiver Type: Powerston                      | Count: 14
# Receiver Type: West Justinberg                | Count: 14
# Receiver Type: Edwardport                     | Count: 14
# Receiver Type: Lake Adriennechester           | Count: 14
# Receiver Type: North Jeffreychester           | Count: 14
# Receiver Type: Bushbury                       | Count: 14
# Receiver Type: Chrisport                      | Count: 14
# Receiver Type: South William                  | Count: 14
# Receiver Type: East Daniel                    | Count: 14
# Receiver Type: Heatherhaven                   | Count: 14
# Receiver Type: Johnsonberg                    | Count: 14
# Receiver Type: North Robinville               | Count: 14
# Receiver Type: North Kimberlyland             | Count: 14
# Receiver Type: Port Dominique                 | Count: 14
# Receiver Type: Port Sarah                     | Count: 14
# Receiver Type: Bobbyfort                      | Count: 14
# Receiver Type: East Ginafort                  | Count: 14
# Receiver Type: Castilloshire                  | Count: 14
# Receiver Type: West Aliciaburgh               | Count: 14
# Receiver Type: Lake Mitchellbury              | Count: 14
# Receiver Type: South Davidstad                | Count: 14
# Receiver Type: New Michaelport                | Count: 14
# Receiver Type: Andersonview                   | Count: 14
# Receiver Type: Port Gregory                   | Count: 14
# Receiver Type: Port Jason                     | Count: 14
# Receiver Type: New Dustin                     | Count: 14
# Receiver Type: West Jeffreyfurt               | Count: 14
# Receiver Type: Jessicatown                    | Count: 14
# Receiver Type: Port Brandon                   | Count: 14
# Receiver Type: Rodriguezborough               | Count: 14
# Receiver Type: South Steven                   | Count: 14
# Receiver Type: Lake Rachelburgh               | Count: 14
# Receiver Type: Brooksmouth                    | Count: 14
# Receiver Type: Christophertown                | Count: 14
# Receiver Type: Langburgh                      | Count: 14
# Receiver Type: Proctorville                   | Count: 14
# Receiver Type: Port Derekland                 | Count: 14
# Receiver Type: Port Chaseport                 | Count: 14
# Receiver Type: Huynhmouth                     | Count: 14
# Receiver Type: Gilbertborough                 | Count: 14
# Receiver Type: Connerland                     | Count: 14
# Receiver Type: Lewismouth                     | Count: 14
# Receiver Type: Matthewhaven                   | Count: 14
# Receiver Type: Bradleyland                    | Count: 14
# Receiver Type: Port Margaretport              | Count: 14
# Receiver Type: Carlosfurt                     | Count: 14
# Receiver Type: Susanville                     | Count: 14
# Receiver Type: Huffmouth                      | Count: 14
# Receiver Type: Lake Gloria                    | Count: 14
# Receiver Type: Pittsville                     | Count: 14
# Receiver Type: Olsonland                      | Count: 14
# Receiver Type: Robertview                     | Count: 14
# Receiver Type: Turnerhaven                    | Count: 14
# Receiver Type: New Travisland                 | Count: 14
# Receiver Type: Stephanieberg                  | Count: 14
# Receiver Type: Paynestad                      | Count: 14
# Receiver Type: Lisaborough                    | Count: 14
# Receiver Type: Carolinebury                   | Count: 14
# Receiver Type: East Cynthiahaven              | Count: 14
# Receiver Type: Port Angelafurt                | Count: 14
# Receiver Type: Ramirezhaven                   | Count: 14
# Receiver Type: Rebeccaview                    | Count: 14
# Receiver Type: Darinland                      | Count: 14
# Receiver Type: East Peter                     | Count: 14
# Receiver Type: New Robert                     | Count: 14
# Receiver Type: West Jacquelineland            | Count: 14
# Receiver Type: Diazshire                      | Count: 14
# Receiver Type: Paulaburgh                     | Count: 14
# Receiver Type: South Michaelfurt              | Count: 14
# Receiver Type: New Michael                    | Count: 14
# Receiver Type: Anthonyport                    | Count: 14
# Receiver Type: Christinahaven                 | Count: 14
# Receiver Type: Port Michaelport               | Count: 14
# Receiver Type: Carterton                      | Count: 14
# Receiver Type: Vasquezberg                    | Count: 14
# Receiver Type: East Davidbury                 | Count: 14
# Receiver Type: Shelbyland                     | Count: 14
# Receiver Type: Ashleeside                     | Count: 14
# Receiver Type: Jacobmouth                     | Count: 14
# Receiver Type: Port Traci                     | Count: 14
# Receiver Type: Port Kristinechester           | Count: 14
# Receiver Type: Lake Lance                     | Count: 14
# Receiver Type: South Donaldshire              | Count: 14
# Receiver Type: Gonzalezstad                   | Count: 14
# Receiver Type: New Alexismouth                | Count: 14
# Receiver Type: South Eric                     | Count: 14
# Receiver Type: West Alexandra                 | Count: 14
# Receiver Type: Shaneport                      | Count: 14
# Receiver Type: Adamland                       | Count: 14
# Receiver Type: Ortizmouth                     | Count: 14
# Receiver Type: Woodsfurt                      | Count: 14
# Receiver Type: Kingville                      | Count: 14
# Receiver Type: Rayberg                        | Count: 14
# Receiver Type: Brownville                     | Count: 14
# Receiver Type: South Meganland                | Count: 14
# Receiver Type: Hallton                        | Count: 14
# Receiver Type: West Kevin                     | Count: 14
# Receiver Type: Randyville                     | Count: 14
# Receiver Type: Pottertown                     | Count: 14
# Receiver Type: East Jordanborough             | Count: 14
# Receiver Type: East Kimberlymouth             | Count: 14
# Receiver Type: North Michaelville             | Count: 14
# Receiver Type: Roberttown                     | Count: 14
# Receiver Type: South Yolanda                  | Count: 14
# Receiver Type: Port Todd                      | Count: 14
# Receiver Type: North Hollyland                | Count: 14
# Receiver Type: Murrayside                     | Count: 14
# Receiver Type: Port Courtneyland              | Count: 14
# Receiver Type: Barreratown                    | Count: 14
# Receiver Type: Hollandburgh                   | Count: 14
# Receiver Type: East Stephenton                | Count: 14
# Receiver Type: Lake Cody                      | Count: 14
# Receiver Type: South Elizabeth                | Count: 14
# Receiver Type: Port Paulaton                  | Count: 14
# Receiver Type: North Sherribury               | Count: 14
# Receiver Type: Hunterbury                     | Count: 14
# Receiver Type: Lake Gregory                   | Count: 14
# Receiver Type: Whiteside                      | Count: 14
# Receiver Type: Lisaview                       | Count: 14
# Receiver Type: North Nathanville              | Count: 14
# Receiver Type: North Raymond                  | Count: 14
# Receiver Type: Mooreburgh                     | Count: 14
# Receiver Type: Beckville                      | Count: 14
# Receiver Type: South Gabrielmouth             | Count: 14
# Receiver Type: North Lisaburgh                | Count: 14
# Receiver Type: North Christopher              | Count: 14
# Receiver Type: West Mariashire                | Count: 14
# Receiver Type: West Carrieberg                | Count: 14
# Receiver Type: Jonesland                      | Count: 14
# Receiver Type: Ariasbury                      | Count: 14
# Receiver Type: South Yvettestad               | Count: 14
# Receiver Type: New Tammyhaven                 | Count: 14
# Receiver Type: Biancaton                      | Count: 14
# Receiver Type: Kinghaven                      | Count: 14
# Receiver Type: New Christopherburgh           | Count: 14
# Receiver Type: Butlerborough                  | Count: 14
# Receiver Type: East Nathan                    | Count: 14
# Receiver Type: Nicoleside                     | Count: 14
# Receiver Type: Mcfarlandhaven                 | Count: 14
# Receiver Type: South Nicoleberg               | Count: 14
# Receiver Type: New Carrie                     | Count: 14
# Receiver Type: Mcdanielmouth                  | Count: 14
# Receiver Type: Patriciamouth                  | Count: 14
# Receiver Type: North Tiffanyfort              | Count: 14
# Receiver Type: South Waynefurt                | Count: 14
# Receiver Type: Robertside                     | Count: 14
# Receiver Type: New Kellytown                  | Count: 14
# Receiver Type: Shelleyburgh                   | Count: 14
# Receiver Type: Andersonland                   | Count: 14
# Receiver Type: Nguyenview                     | Count: 14
# Receiver Type: West Danielview                | Count: 14
# Receiver Type: Mendozabury                    | Count: 14
# Receiver Type: Kimberlyview                   | Count: 14
# Receiver Type: Keithstad                      | Count: 14
# Receiver Type: East Heatherbury               | Count: 14
# Receiver Type: Stephenchester                 | Count: 14
# Receiver Type: Port David                     | Count: 14
# Receiver Type: East Nicole                    | Count: 14
# Receiver Type: Morenoborough                  | Count: 14
# Receiver Type: Vancebury                      | Count: 14
# Receiver Type: New Daryl                      | Count: 14
# Receiver Type: North Marcusbury               | Count: 14
# Receiver Type: Perezhaven                     | Count: 14
# Receiver Type: Johnville                      | Count: 14
# Receiver Type: Blakehaven                     | Count: 14
# Receiver Type: West Garretthaven              | Count: 14
# Receiver Type: Moralesfort                    | Count: 14
# Receiver Type: Cameronfurt                    | Count: 14
# Receiver Type: Anthonystad                    | Count: 14
# Receiver Type: East Antoniobury               | Count: 14
# Receiver Type: New Ryanmouth                  | Count: 14
# Receiver Type: Melaniehaven                   | Count: 14
# Receiver Type: Fowlerburgh                    | Count: 14
# Receiver Type: Robertfurt                     | Count: 14
# Receiver Type: West Juanchester               | Count: 14
# Receiver Type: South Lucasview                | Count: 14
# Receiver Type: Johnsonville                   | Count: 14
# Receiver Type: West Troyview                  | Count: 14
# Receiver Type: Port Timothymouth              | Count: 14
# Receiver Type: North Michael                  | Count: 14
# Receiver Type: Port Mariemouth                | Count: 14
# Receiver Type: Fernandezberg                  | Count: 14
# Receiver Type: Michealstad                    | Count: 14
# Receiver Type: Port Peggyshire                | Count: 14
# Receiver Type: Port Maryshire                 | Count: 14
# Receiver Type: South Anthonyside              | Count: 14
# Receiver Type: Kempstad                       | Count: 14
# Receiver Type: Kenthaven                      | Count: 14
# Receiver Type: Petersonmouth                  | Count: 14
# Receiver Type: Port Shannonhaven              | Count: 14
# Receiver Type: Toddstad                       | Count: 14
# Receiver Type: Jensenland                     | Count: 14
# Receiver Type: Davidland                      | Count: 14
# Receiver Type: Rogersfort                     | Count: 14
# Receiver Type: Sharpfurt                      | Count: 14
# Receiver Type: Chenview                       | Count: 14
# Receiver Type: Port Seanshire                 | Count: 14
# Receiver Type: Goodmanfort                    | Count: 14
# Receiver Type: Brooksborough                  | Count: 14
# Receiver Type: New Mark                       | Count: 14
# Receiver Type: South Jasminechester           | Count: 14
# Receiver Type: South Shirleymouth             | Count: 14
# Receiver Type: Richardton                     | Count: 14
# Receiver Type: Jeanshire                      | Count: 14
# Receiver Type: Karenfort                      | Count: 14
# Receiver Type: Taylorport                     | Count: 14
# Receiver Type: Ellisborough                   | Count: 14
# Receiver Type: Port Joshua                    | Count: 14
# Receiver Type: East Sheenahaven               | Count: 14
# Receiver Type: North Erikhaven                | Count: 14
# Receiver Type: East Tiffanyview               | Count: 14
# Receiver Type: Lake Sheilaland                | Count: 14
# Receiver Type: Wardshire                      | Count: 14
# Receiver Type: Christinehaven                 | Count: 14
# Receiver Type: Joshuahaven                    | Count: 14
# Receiver Type: Nelsonbury                     | Count: 14
# Receiver Type: New James                      | Count: 14
# Receiver Type: West Amandaport                | Count: 14
# Receiver Type: Changview                      | Count: 14
# Receiver Type: Davidtown                      | Count: 14
# Receiver Type: New Shauntown                  | Count: 14
# Receiver Type: East Emily                     | Count: 14
# Receiver Type: West Monica                    | Count: 14
# Receiver Type: South Marymouth                | Count: 14
# Receiver Type: West Brittany                  | Count: 14
# Receiver Type: Bruceburgh                     | Count: 14
# Receiver Type: Sarahside                      | Count: 14
# Receiver Type: East Nathanstad                | Count: 14
# Receiver Type: Lake Kevinport                 | Count: 14
# Receiver Type: New Frederickfort              | Count: 14
# Receiver Type: South Jason                    | Count: 14
# Receiver Type: New Stephanie                  | Count: 14
# Receiver Type: Nicholsonland                  | Count: 14
# Receiver Type: Lovestad                       | Count: 14
# Receiver Type: Mercerport                     | Count: 14
# Receiver Type: Port Terry                     | Count: 14
# Receiver Type: North Amanda                   | Count: 14
# Receiver Type: Lake Douglas                   | Count: 14
# Receiver Type: Lake Tracytown                 | Count: 14
# Receiver Type: Shortfort                      | Count: 14
# Receiver Type: Port Amberfurt                 | Count: 14
# Receiver Type: East Stephaniefort             | Count: 14
# Receiver Type: Nicoleberg                     | Count: 14
# Receiver Type: Heatherburgh                   | Count: 14
# Receiver Type: New Brandyhaven                | Count: 14
# Receiver Type: East Tasha                     | Count: 14
# Receiver Type: New Matthewton                 | Count: 14
# Receiver Type: Victorton                      | Count: 14
# Receiver Type: Port Marc                      | Count: 14
# Receiver Type: Kimberlymouth                  | Count: 14
# Receiver Type: Port Curtisside                | Count: 14
# Receiver Type: South Jenniferburgh            | Count: 14
# Receiver Type: South Richard                  | Count: 14
# Receiver Type: Perryton                       | Count: 14
# Receiver Type: Reedview                       | Count: 14
# Receiver Type: Cummingschester                | Count: 14
# Receiver Type: Lake Catherine                 | Count: 14
# Receiver Type: West Bradley                   | Count: 14
# Receiver Type: East Jamesmouth                | Count: 14
# Receiver Type: Garciashire                    | Count: 14
# Receiver Type: West David                     | Count: 14
# Receiver Type: Danielsview                    | Count: 14
# ...
# Receiver Type: Brownbury                      | Count: 14
# Receiver Type: West Meganmouth                | Count: 14
# Receiver Type: Lake Lindseystad               | Count: 14
# Receiver Type: Theresabury                    | Count: 14
# Receiver Type: South Michelleport             | Count: 14
# Receiver Type: Lisabury                       | Count: 14
# Receiver Type: Josephside                     | Count: 14
# Receiver Type: Harrisfurt                     | Count: 14
# Receiver Type: East Daisybury                 | Count: 14
# Receiver Type: Westshire                      | Count: 14
# Receiver Type: Shawhaven                      | Count: 14
# Receiver Type: Comptonside                    | Count: 14
# Receiver Type: Maryside                       | Count: 14
# Receiver Type: North Dawn                     | Count: 14
# Receiver Type: South Sheryl                   | Count: 14
# Receiver Type: Martinchester                  | Count: 14
# Receiver Type: Andreaberg                     | Count: 14
# Receiver Type: Delgadofort                    | Count: 14
# Receiver Type: West Jacob                     | Count: 14
# Receiver Type: Davisport                      | Count: 14
# Receiver Type: East Mark                      | Count: 14
# Receiver Type: East Amandaberg                | Count: 14
# Receiver Type: Cruzland                       | Count: 14
# Receiver Type: New Olivia                     | Count: 14
# Receiver Type: West Jacquelinefort            | Count: 14
# Receiver Type: North Tanner                   | Count: 14
# Receiver Type: Michaelside                    | Count: 14
# Receiver Type: Scottbury                      | Count: 14
# Receiver Type: Lake Christian                 | Count: 14
# Receiver Type: New Kimberly                   | Count: 14
# Receiver Type: Ginaview                       | Count: 14
# Receiver Type: West Josephland                | Count: 14
# Receiver Type: Lauratown                      | Count: 14
# Receiver Type: South Lisa                     | Count: 14
# Receiver Type: West John                      | Count: 14
# Receiver Type: West Michaelton                | Count: 14
# Receiver Type: North Kelly                    | Count: 14
# Receiver Type: South Mirandamouth             | Count: 14
# Receiver Type: Amandaburgh                    | Count: 14
# Receiver Type: New Laura                      | Count: 14
# Receiver Type: Halltown                       | Count: 14
# Receiver Type: Lake Dustin                    | Count: 14
# Receiver Type: Ramosberg                      | Count: 14
# Receiver Type: Johnsonchester                 | Count: 14
# Receiver Type: Meganburgh                     | Count: 14
# Receiver Type: Taraside                       | Count: 14
# Receiver Type: Ellisshire                     | Count: 14
# Receiver Type: Bradfurt                       | Count: 14
# Receiver Type: Wyattton                       | Count: 14
# Receiver Type: Port Williamtown               | Count: 14
# Receiver Type: Crawfordchester                | Count: 14
# Receiver Type: Lorifurt                       | Count: 14
# Receiver Type: Collierburgh                   | Count: 14
# Receiver Type: New Larryshire                 | Count: 14
# Receiver Type: Lake Kaylamouth                | Count: 14
# Receiver Type: Lake Stephenchester            | Count: 14
# Receiver Type: Cookstad                       | Count: 14
# Receiver Type: Kirkfort                       | Count: 14
# Receiver Type: Poolebury                      | Count: 14
# Receiver Type: New Erikamouth                 | Count: 14
# Receiver Type: Billyland                      | Count: 14
# Receiver Type: South Craigborough             | Count: 14
# Receiver Type: Lake Joshuabury                | Count: 14
# Receiver Type: Pooleside                      | Count: 14
# Receiver Type: New Dakotahaven                | Count: 14
# Receiver Type: West Lindseyside               | Count: 14
# Receiver Type: North Shawnastad               | Count: 14
# Receiver Type: North Amy                      | Count: 14
# Receiver Type: Natalieside                    | Count: 14
# Receiver Type: Annaborough                    | Count: 14
# Receiver Type: Port Philipmouth               | Count: 14
# Receiver Type: East Shirley                   | Count: 14
# Receiver Type: New Donnahaven                 | Count: 14
# Receiver Type: Jamesview                      | Count: 14
# Receiver Type: North Nicholasborough          | Count: 14
# Receiver Type: Port Robertmouth               | Count: 14
# Receiver Type: South Emily                    | Count: 14
# Receiver Type: North Ricardo                  | Count: 14
# Receiver Type: Tylermouth                     | Count: 14
# Receiver Type: Rodneyport                     | Count: 14
# Receiver Type: New Jeffreyhaven               | Count: 14
# Receiver Type: North Josephmouth              | Count: 14
# Receiver Type: East Robert                    | Count: 14
# Receiver Type: Allenborough                   | Count: 14
# Receiver Type: Fernandezchester               | Count: 14
# Receiver Type: Birdview                       | Count: 14
# Receiver Type: West Sara                      | Count: 14
# Receiver Type: Jamesborough                   | Count: 14
# Receiver Type: North Haleyhaven               | Count: 14
# Receiver Type: Lake Williamhaven              | Count: 14
# Receiver Type: Jarvisshire                    | Count: 14
# Receiver Type: New Adrian                     | Count: 14
# Receiver Type: West Barry                     | Count: 14
# Receiver Type: New Loriberg                   | Count: 14
# Receiver Type: East Michaelview               | Count: 14
# Receiver Type: Grossport                      | Count: 14
# Receiver Type: East Kevinberg                 | Count: 14
# Receiver Type: Dawsonberg                     | Count: 14
# Receiver Type: New Juliaton                   | Count: 14
# Receiver Type: Franklinview                   | Count: 14
# Receiver Type: East Travis                    | Count: 14
# Receiver Type: Payneland                      | Count: 14
# Receiver Type: New Melanie                    | Count: 14
# Receiver Type: Lake Shawn                     | Count: 14
# Receiver Type: Rubioborough                   | Count: 14
# Receiver Type: Lake Brandibury                | Count: 14
# Receiver Type: Jessicaland                    | Count: 14
# Receiver Type: Williamsborough                | Count: 14
# Receiver Type: Kennethmouth                   | Count: 14
# Receiver Type: Woodardview                    | Count: 14
# Receiver Type: South Alanville                | Count: 14
# Receiver Type: Ianland                        | Count: 14
# Receiver Type: East Kevin                     | Count: 14
# Receiver Type: Jenkinsfurt                    | Count: 14
# Receiver Type: West Davidview                 | Count: 14
# Receiver Type: Lake Victoriaton               | Count: 14
# Receiver Type: Kelleystad                     | Count: 14
# Receiver Type: Darinview                      | Count: 14
# Receiver Type: North Janetland                | Count: 14
# Receiver Type: West Donaldmouth               | Count: 14
# Receiver Type: East Sheriton                  | Count: 14
# Receiver Type: Gloriaview                     | Count: 14
# Receiver Type: Carlostown                     | Count: 14
# Receiver Type: Mathistown                     | Count: 14
# Receiver Type: Dunnbury                       | Count: 14
# Receiver Type: South Michael                  | Count: 14
# Receiver Type: South Mary                     | Count: 14
# Receiver Type: West Paulfort                  | Count: 14
# Receiver Type: Erikashire                     | Count: 14
# Receiver Type: Riverafort                     | Count: 14
# Receiver Type: Port Douglasland               | Count: 14
# Receiver Type: Port Jonathanton               | Count: 14
# Receiver Type: Hayesfort                      | Count: 14
# Receiver Type: Lake Brandonborough            | Count: 14
# Receiver Type: Elizabethberg                  | Count: 14
# Receiver Type: South Heather                  | Count: 14
# Receiver Type: Rodneyborough                  | Count: 14
# Receiver Type: New Jessicabury                | Count: 14
# Receiver Type: New Melindashire               | Count: 14
# Receiver Type: Caitlynhaven                   | Count: 14
# Receiver Type: North Lawrence                 | Count: 14
# Receiver Type: East Debramouth                | Count: 14
# Receiver Type: West Ashleymouth               | Count: 14
# Receiver Type: North Lydiaberg                | Count: 14
# Receiver Type: Delacruzborough                | Count: 14
# Receiver Type: Robertville                    | Count: 14
# Receiver Type: Gilbertfurt                    | Count: 14
# Receiver Type: Port Jonathanhaven             | Count: 14
# Receiver Type: Nathanstad                     | Count: 14
# Receiver Type: Jacquelineshire                | Count: 14
# Receiver Type: Kennethside                    | Count: 14
# Receiver Type: Greenville                     | Count: 14
# Receiver Type: Oneillland                     | Count: 14
# Receiver Type: Suzanneton                     | Count: 14
# Receiver Type: Myerstown                      | Count: 14
# Receiver Type: West Dustinberg                | Count: 14
# Receiver Type: North Stephanieborough         | Count: 14
# Receiver Type: Johnhaven                      | Count: 14
# Receiver Type: Davisfort                      | Count: 14
# Receiver Type: Port Thomas                    | Count: 14
# Receiver Type: Lake Larryborough              | Count: 14
# Receiver Type: Port Cindyberg                 | Count: 14
# Receiver Type: Mariefurt                      | Count: 14
# Receiver Type: Bennettton                     | Count: 14
# Receiver Type: South Benjamin                 | Count: 14
# Receiver Type: Mayburgh                       | Count: 14
# Receiver Type: Lauraport                      | Count: 14
# Receiver Type: Patrickfort                    | Count: 14
# Receiver Type: North Joshua                   | Count: 14
# Receiver Type: Amandafurt                     | Count: 14
# Receiver Type: Clarkton                       | Count: 14
# Receiver Type: South Paul                     | Count: 14
# Receiver Type: Lake Sonya                     | Count: 14
# Receiver Type: Teresastad                     | Count: 14
# Receiver Type: Carrborough                    | Count: 14
# Receiver Type: Port Cody                      | Count: 14
# Receiver Type: Gutierrezmouth                 | Count: 14
# Receiver Type: North Jacobhaven               | Count: 14
# Receiver Type: Travishaven                    | Count: 14
# Receiver Type: Rodneyfurt                     | Count: 14
# Receiver Type: South Jamie                    | Count: 14
# Receiver Type: East Renee                     | Count: 14
# Receiver Type: Nielsenberg                    | Count: 14
# Receiver Type: North Laura                    | Count: 14
# Receiver Type: Thomasport                     | Count: 14
# Receiver Type: Jessicaburgh                   | Count: 14
# Receiver Type: Port Johnside                  | Count: 14
# Receiver Type: Matthewmouth                   | Count: 14
# Receiver Type: Port Kellifort                 | Count: 14
# Receiver Type: Andrewsport                    | Count: 14
# Receiver Type: Lanechester                    | Count: 14
# Receiver Type: New Steven                     | Count: 14
# Receiver Type: South Sandra                   | Count: 14
# Receiver Type: Lake Jeffery                   | Count: 14
# Receiver Type: Shelbychester                  | Count: 14
# Receiver Type: Spencermouth                   | Count: 28
# Receiver Type: Moorechester                   | Count: 28
# Receiver Type: Lake Mary                      | Count: 28
# Receiver Type: Smithshire                     | Count: 28
# Receiver Type: Lake Daniel                    | Count: 28
# Receiver Type: Kellybury                      | Count: 28
# Receiver Type: Greenton                       | Count: 28
# Receiver Type: North Lori                     | Count: 28
# Receiver Type: West James                     | Count: 28
# Receiver Type: North Christina                | Count: 28
# Receiver Type: Davidmouth                     | Count: 28
# Receiver Type: Allenmouth                     | Count: 28
# Receiver Type: Stevenmouth                    | Count: 28
# Receiver Type: Emilymouth                     | Count: 28
# Receiver Type: Ashleyborough                  | Count: 28
# Receiver Type: New Derek                      | Count: 28
# Receiver Type: Williamsfort                   | Count: 28
# Receiver Type: Port Samantha                  | Count: 28
# Receiver Type: Longmouth                      | Count: 28
# Receiver Type: Port Richard                   | Count: 28
# Receiver Type: Lake Rebeccaton                | Count: 28
# Receiver Type: Jenniferbury                   | Count: 28
# Receiver Type: Brandonhaven                   | Count: 28
# Receiver Type: Christopherchester             | Count: 28
# Receiver Type: West Richard                   | Count: 28
# Receiver Type: Sarahaven                      | Count: 28
# Receiver Type: Phillipston                    | Count: 28
# Receiver Type: Robertton                      | Count: 28
# Receiver Type: Josephton                      | Count: 28
# Receiver Type: Markfurt                       | Count: 28
# Receiver Type: South Mark                     | Count: 28
# Receiver Type: East Michael                   | Count: 28
# Receiver Type: New Christopher                | Count: 42

# %% [markdown]
#                 24. Providers with the most expired food items

# %%
query=''' 
SELECT 
    p.Name AS Provider_Name,
    COUNT(f.Food_ID) AS Expired_food_count
FROM foodlistings f
JOIN providers p ON f.Provider_ID=p.Provider_ID
WHERE f.Expiry_Date<CURDATE()
GROUP BY p.Provider_ID, p.Name
ORDER BY Expired_food_count DESC
LIMIT 5;

'''
cursor.execute(query)

results = cursor.fetchall()

print("Providers with the most expired food items:")
print("-" * 40)
for Provider_ID_, Expired_food_count in results:
    print(f"Provider: {Provider_ID_:<30} | Count: {Expired_food_count:<12}  ")
# Out:
# Providers with the most expired food items:
# ----------------------------------------
# Provider: Barry Group                    | Count: 990
# Provider: Daniels-Kim                    | Count: 825
# Provider: Campbell LLC                   | Count: 825
# Provider: Smith Group                    | Count: 825
# Provider: Evans, Wright and Mitchell     | Count: 660

# %%
# %%writefile food.py
import streamlit as st
import pandas as pd
import mysql.connector
import plotly.express as px
import seaborn as sns


# Database Connection
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Sadguro161092",
    database="DSB42"
)
cursor = connection.cursor()

# Streamlit Configuration
st.set_page_config(page_title="Local Food Waste Management Dashboard", layout="wide", page_icon="🍽️")
st.sidebar.title("Navigation")
page = st.sidebar.radio("Go to", ['Project Introduction', 'Data Overview', 'Visualizations', 'CRUD Operations', 'SQL Queries', 'Writer Info'])

if page == 'Project Introduction':
    st.title("🍽️ Local Food Waste Management System")

    # Project Overview
    st.markdown("### 🌐 Project Overview")
    st.markdown("""
    The **Local Food Waste Management System** is designed to support the **redistribution of surplus food**  
    by connecting **providers** (e.g., restaurants, grocery stores) with **receivers** (e.g., NGOs, shelters).  
    The aim is to **reduce food waste** and tackle **community hunger** using structured, data-driven processes.
    """)

    st.image("D:/GUVI2/Foodwastemanagemnt/localfwm.png", caption="Smart Food Redistribution", use_container_width=True)

    # Why This Matters
    st.markdown("### 📍 Why This Matters")
    st.markdown("""
    - Over **1.3 billion tons** of food is wasted globally each year  
    - Millions face **food insecurity** despite available surplus  
    - This system bridges the gap between **excess and need**
    """)

    # Key Features
    st.markdown("### ⚙️ Key Features")
    st.markdown("""
    - City-level tracking of providers and receivers  
    - Real-time listings with expiry visibility  
    - Dashboards to analyze donations and claims  
    - Shelf-life tracking to prevent spoilage  
    - Direct contact access for coordination  
    """)

    st.image("D:/GUVI2/Foodwastemanagemnt/localfwm2.png", caption="From Waste to Worth", use_container_width=True)

    st.markdown("---")

    # Project Objectives
    st.markdown("### 🎯 Project Objectives")
    st.markdown("""
    - Ensure **timely collection and delivery** of surplus food  
    - Use **data analytics** to improve distribution patterns  
    - Enable **transparency** through a SQL-integrated dashboard  
    """)

    # Technologies Used
    st.markdown("### 💻 Technologies Used")
    st.markdown("""
    - **Frontend**: Streamlit  
    - **Database**: MySQL  
    - **Backend**: Python  
    - **Visualization**: Matplotlib, Seaborn, Plotly  
    """)

    st.markdown("---")
    st.success("🔍 Explore the **'SQL Queries'** section to gain insights into food distribution patterns.")





elif page == 'Data Overview':
    st.title("📊 Data Overview")

    st.markdown("""
    Below are the datasets used in the **Local Food Waste Management** system.  
    Use the dropdown to explore the structure and contents of each database table.
    """)

    table = st.selectbox("📁 Select Table", ["providers", "receivers", "foodlistings", "claims"])
    df = pd.read_sql(f"SELECT * FROM {table}", connection)

    st.markdown(f"**📌 Table Selected:** `{table}`")
    st.markdown(f"**Rows:** {df.shape[0]}  **Columns:** {df.shape[1]}")

    

    st.markdown("### 🔍 Table Preview")
    st.dataframe(df, use_container_width=True)

#------------------------------------------------------------------------------------------------------------------
elif page=='Visualizations':
    providers = pd.read_sql("SELECT * FROM providers", connection)
    receivers = pd.read_sql("SELECT * FROM receivers", connection)
    foodlistings = pd.read_sql("SELECT * FROM foodlistings", connection)
    claims = pd.read_sql("SELECT * FROM claims", connection)
    st.title("📊 EDA: Food Sharing System")

    st.header("1. Dataset Overview")
    st.write("**Food Listings:**", foodlistings.shape)
    st.write("**Providers:**", providers.shape)
    st.write("**Receivers:**", receivers.shape)
    st.write("**Claims:**", claims.shape)

    # Show sample data
    with st.expander("Show sample data"):
        st.subheader("Food Listings Sample")
        st.dataframe(foodlistings.head())

        st.subheader("Providers Sample")
        st.dataframe(providers.head())

        st.subheader("Receivers Sample")
        st.dataframe(receivers.head())

        st.subheader("Claims Sample")
        st.dataframe(claims.head())

    # --- Food Listings EDA ---
    st.header("Food Listings Insights")

   

    # Food type breakdown
    if 'Food_Type' in foodlistings.columns:
        fig2 = px.pie(foodlistings, names='Food_Type', title='Food Type Distribution')
        st.plotly_chart(fig2)

    # Meal type
    if 'Meal_Type' in foodlistings.columns:
        meal_counts = foodlistings['Meal_Type'].value_counts().reset_index()
        meal_counts.columns = ['Meal_Type', 'Count']

        fig3 = px.bar(
            meal_counts,
            x='Meal_Type', y='Count',
            labels={'Meal_Type': 'Meal Type', 'Count': 'Count'},
            title="Meal Type Distribution"
        )


    



    # --- Receiver Analysis ---
    st.header(" Receiver Insights")

   
    if 'Type' in receivers.columns:
        fig8 = px.pie(receivers, names='Type', title='Receiver Type Breakdown')
        st.plotly_chart(fig8)

    # --- Claims Overview ---
    st.header("Claim Status Summary")

    if 'Status' in claims.columns:
        fig9 = px.pie(claims, names='Status', title='Claim Status Distribution')
        st.plotly_chart(fig9)

    if 'Timestamp' in claims.columns:
        claims['Timestamp'] = pd.to_datetime(claims['Timestamp'], errors='coerce')
        claims_by_day = claims['Timestamp'].dt.date.value_counts().sort_index()
        fig10 = px.line(x=claims_by_day.index, y=claims_by_day.values,
                        labels={'x': 'Date', 'y': 'Number of Claims'},
                        title='Claims Over Time')
        st.plotly_chart(fig10)
    
    #------------------------------------------------------------------------------------------------------------
elif page == 'CRUD Operations':
    st.title("🛠️ CRUD: Manage Food Sharing Data")

    menu = st.sidebar.selectbox("Choose Table", ["providers", "receivers", "foodlistings", "claims"])

    def fetch_table(table_name):
        df = pd.read_sql(f"SELECT * FROM {table_name}", connection)
        df.reset_index(drop=True, inplace=True)
        return df

    def delete_record(table, id_col, record_id):
        cursor.execute(f"DELETE FROM {table} WHERE {id_col} = %s", (record_id,))
        connection.commit()

    # ------------ PROVIDERS ------------
    if menu == "providers":
        st.header("📦 Providers")
        df = fetch_table("providers")
        st.dataframe(df)

        with st.form("provider_form"):
            st.subheader("Manage Providers")
            mode = st.radio("Action", ["Add", "Delete"], horizontal=True)
            pid = st.number_input("Provider ID (for delete only)", min_value=1, step=1)

            name = st.text_input("Name")
            type_ = st.selectbox("Type", ["Restaurant", "Grocery Store", "Catering Service", "Supermarket"])
            address = st.text_input("Address")
            city = st.text_input("City")
            contact = st.text_input("Contact")

            submitted = st.form_submit_button("Submit")

            if submitted:
                if mode == "Add":
                    if all([name, type_, address, city, contact]):
                        cursor.execute("INSERT INTO providers (Name, Type, Address, City, Contact) VALUES (%s, %s, %s, %s, %s)",
                                       (name, type_, address, city, contact))
                        connection.commit()
                        st.success("✅ Provider added.")
                        st.experimental_rerun()
                    else:
                        st.warning("Please fill in all fields.")
                elif mode == "Delete":
                    delete_record("providers", "Provider_ID", pid)
                    st.success("✅ Provider deleted.")
                    st.experimental_rerun()

    # ------------ RECEIVERS ------------
    elif menu == "receivers":
        st.header("🏢 Receivers")
        df = fetch_table("receivers")
        st.dataframe(df)

        with st.form("receiver_form"):
            st.subheader("Manage Receivers")
            mode = st.radio("Action", ["Add", "Update", "Delete"], horizontal=True)
            rid = st.number_input("Receiver ID (for update/delete)", min_value=1, step=1)

            name = st.text_input("Name")
            type_ = st.selectbox("Type", ["NGO", "Shelter", "Charity", "Individual"])
            city = st.text_input("City")
            contact = st.text_input("Contact")

            submitted = st.form_submit_button("Submit")

            if submitted:
                if mode == "Add":
                    if all([name, type_, city, contact]):
                        cursor.execute("INSERT INTO receivers (Name, Type, City, Contact) VALUES (%s, %s, %s, %s)",
                                       (name, type_, city, contact))
                        connection.commit()
                        st.success("✅ Receiver added.")
                        st.experimental_rerun()
                    else:
                        st.warning("Fill all fields to add.")
                elif mode == "Update":
                    cursor.execute("UPDATE receivers SET Name=%s, Type=%s, City=%s, Contact=%s WHERE Receiver_ID=%s",
                                   (name, type_, city, contact, rid))
                    connection.commit()
                    st.success("✅ Receiver updated.")
                    st.experimental_rerun()
                elif mode == "Delete":
                    delete_record("receivers", "Receiver_ID", rid)
                    st.success("✅ Receiver deleted.")
                    st.experimental_rerun()

    # ------------ FOOD LISTINGS ------------
    elif menu == "foodlistings":
        st.header("🍱 Food Listings")
        df = fetch_table("foodlistings")
        df_providers = fetch_table("providers")
        st.dataframe(df)

        with st.form("food_form"):
            st.subheader("Manage Food Listings")
            mode = st.radio("Action", ["Add", "Delete"], horizontal=True)
            fid = st.number_input("Food ID (for delete only)", min_value=1, step=1)

            food_name = st.text_input("Food Name")
            quantity = st.number_input("Quantity", min_value=1)
            expiry = st.date_input("Expiry Date")
            provider_id = st.number_input("Provider ID", min_value=1, step=1)
            food_type = st.selectbox("Food Type", ["Vegetarian", "Non-Vegetarian", "Vegan"])
            meal_type = st.selectbox("Meal Type", ["Breakfast", "Lunch", "Dinner", "Snacks"])

            submitted = st.form_submit_button("Submit")

            if submitted:
                if mode == "Add":
                    matched = df_providers[df_providers["Provider_ID"] == provider_id]
                    if not matched.empty:
                        row = matched.iloc[0]
                        cursor.execute("""
                            INSERT INTO foodlistings (Food_Name, Quantity, Expiry_Date, Provider_ID,
                            Provider_Type, Location, Food_Type, Meal_Type)
                            VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
                        """, (food_name, quantity, expiry, provider_id, row["Type"], row["City"], food_type, meal_type))
                        connection.commit()
                        st.success("✅ Food added.")
                        st.experimental_rerun()
                    else:
                        st.error("Invalid Provider ID.")
                elif mode == "Delete":
                    delete_record("foodlistings", "Food_ID", fid)
                    st.success("✅ Food deleted.")
                    st.experimental_rerun()

    # ------------ CLAIMS ------------
    elif menu == "claims":
        st.header("📋 Claims")
        df = fetch_table("claims")
        df_food = fetch_table("foodlistings")
        df_receivers = fetch_table("receivers")
        st.dataframe(df)

        with st.form("claim_form"):
            st.subheader("Manage Claims")
            mode = st.radio("Action", ["Add", "Delete"], horizontal=True)
            cid = st.number_input("Claim ID (for delete only)", min_value=1, step=1)

            food_id = st.selectbox("Food ID", df_food["Food_ID"])
            receiver_id = st.selectbox("Receiver ID", df_receivers["Receiver_ID"])
            status = st.selectbox("Status", ["Pending", "Completed", "Cancelled"])

            submitted = st.form_submit_button("Submit")

            if submitted:
                if mode == "Add":
                    cursor.execute("""
                        INSERT INTO claims (Food_ID, Receiver_ID, Status, Timestamp)
                        VALUES (%s, %s, %s, NOW())
                    """, (food_id, receiver_id, status))
                    connection.commit()
                    st.success("✅ Claim added.")
                    st.experimental_rerun()
                elif mode == "Delete":
                    delete_record("claims", "Claim_ID", cid)
                    st.success("✅ Claim deleted.")
                    st.experimental_rerun()



elif page == 'SQL Queries':
    st.title("🧮 SQL Queries Dashboard")

    queries = {
        "1. Food providers and receivers in each city": """
        SELECT
            p.City,
            COUNT(DISTINCT p.Provider_ID) AS Num_Providers,
            COUNT(DISTINCT r.Receiver_ID) AS Num_Receivers
        FROM providers p
        LEFT JOIN receivers r ON p.City=r.City
        GROUP BY p.City
        """,

        "2. Food provider type contributing most": """
        SELECT 
            p.Type,
            SUM(f.Quantity) AS Food_Total
        FROM foodlistings f
        JOIN providers p on f.Provider_ID=p.Provider_ID
        GROUP BY p.Type
        ORDER BY Food_Total DESC
        LIMIT 1;
        """,

        "3. Contact info of providers in city": f"""
        SELECT DISTINCT Name,Contact
        FROM providers p
        WHERE City=%s;
        """,

        "4. Receivers who claimed most food": """
        SELECT r.Name, SUM(f.Quantity) AS Food_Claimed
        FROM claims c
        JOIN receivers r ON c.Receiver_ID =r.receiver_ID
        JOIN foodlistings f ON c.Food_ID=f.Food_ID
        WHERE c.Status='Completed' 
        GROUP BY r.Name
        ORDER BY Food_Claimed DESC
        LIMIT 1;
        """,

        "5. Total quantity of food available": """
        SELECT SUM(f.quantity) as Total_Food FROM foodlistings f
        """,

        "6. City with highest food listings": """
        SELECT Location AS City, COUNT(*) AS Max_Listings
        FROM foodlistings
        GROUP BY Location
        ORDER BY Max_Listings DESC
        LIMIT 1;
        """,

        "7. Most commonly available food types": """
        SELECT f.Food_Type, COUNT(*) AS Common_Type
        FROM foodlistings f
        GROUP BY f.Food_Type
        ORDER BY Common_Type DESC
        LIMIT 1;
        """,

        "8. Number of food claims per item": """
        SELECT c.Food_ID, COUNT(*) AS Num_Claims
        FROM claims c
        GROUP BY Food_ID
        ORDER BY Num_Claims DESC;
        """,

        "9. Provider with most successful claims": """
        SELECT p.Provider_ID, COUNT(*) AS Succesful_Claims
        FROM claims c
        JOIN foodlistings f ON c.Food_ID=f.Food_ID
        JOIN providers p ON p.Provider_ID= f.Provider_ID
        WHERE c.Status='Completed'
        GROUP BY p.Provider_ID
        ORDER BY Succesful_Claims DESC
        LIMIT 1;
        """,

        "10. Percentage of claim statuses": """
        SELECT 
                Status,
                COUNT(*) AS count,
                ROUND(100.0*COUNT(*)/(SELECT COUNT(*) FROM claims),2) AS Percentage
        FROM claims
        GROUP BY Status
        ORDER BY Percentage DESC;
        """,

        "11. Avg food claimed per receiver": """
        SELECT r.Name, AVG(f.Quantity) AS Avg_Claimed
        FROM claims c
        JOIN receivers r ON c.receiver_ID=r.receiver_ID
        JOIN foodlistings f ON c.Food_ID=f.Food_ID
        GROUP BY r.Name
        """,

        "12. Most claimed meal type": """
        SELECT Meal_Type, COUNT(*) AS Num_claims
        FROM foodlistings f
        JOIN claims c ON f.Food_ID=c.Food_ID
        GROUP BY Meal_type
        ORDER BY Num_claims DESC
        LIMIT 1;
        """,

        "13. Total food donated per provider": """
        SELECT p.Provider_ID, COUNT(*) AS Num_Donated
        FROM providers p
        JOIN foodlistings f ON p.Provider_ID=f.Provider_ID
        GROUP BY Provider_ID
        ORDER BY Num_Donated;
        """,

        "14. Avg claims per receiver": """
        SELECT Receiver_ID, COUNT(*) AS total_claims
        FROM claims
        GROUP BY Receiver_ID
        """,

        "15. Providers with most diverse offerings": """
        SELECT 
            p.Name AS Pname,
            COUNT(DISTINCT f.Food_type) AS Food_Type_Count
        FROM foodlistings f
        JOIN providers p ON p.Provider_ID =f.Provider_ID
        GROUP BY p.Name
        ORDER BY Food_Type_Count DESC
        LIMIT 1;
        """,

        "16. Top 5 active providers": """
        SELECT 
            p.Provider_ID,
            p.Name as Provider_name,
            COUNT(c.Claim_ID)  AS Claim_num
        FROM providers p
        JOIN foodlistings f ON p.Provider_ID=f.Provider_ID
        JOIN claims c ON f.Food_ID=c.Food_ID
        WHERE c.Status='Completed'
        GROUP BY p.Provider_ID,p.Name
        ORDER BY Claim_num DESC
        LIMIT 5; 
        """,

        "17. Distribution of claim status": """
        SELECT 
            Status,
            COUNT(Claim_ID) AS Claim_Count,
            ROUND(COUNT(Claim_ID)/(SELECT COUNT(*) FROM claims)*100,2) AS Claim_Percentage
        FROM claims 
        GROUP BY Status
        """,

        "18. Providers with no claims": """
        SELECT 
            p.Provider_ID,
            p.Name AS Provider_Name
        FROM providers p
        WHERE NOT EXISTS (
            SELECT 1
            FROM foodlistings f
            JOIN claims c ON f.Food_ID=c.Food_ID
            WHERE f.Provider_ID=p.provider_ID
        );
        """,

        "19. Total claims & quantity per meal": """
        SELECT 
            f.Meal_Type,
            COUNT(c.Claim_ID) AS Total_Claims,
            SUM(f.Quantity) AS Total_Quantity
        FROM claims c
        JOIN foodlistings f ON c.Food_ID=f.Food_ID
        GROUP BY f.Meal_Type, f.Quantity
        ORDER BY Total_Quantity DESC
        """,

        "20. Top 10 provider cities": """
        SELECT 
            p.City AS Provider_city,
            COUNT(*) AS Provider_by_city
        FROM providers p
        GROUP BY p.City
        ORDER BY Provider_by_city DESC
        LIMIT 10
        """,

        "21. Most common receiver type": """
        SELECT 
            r.Type as Receiver_type,
            COUNT(*) AS Receiver_type_count
        FROM receivers r
        GROUP BY r.Type
        ORDER BY Receiver_type_count DESC
        LIMIT 1;
        """,

        "22. Receiver type by count": """
        SELECT 
            r.Type AS Receiver_type,
            COUNT(*) AS Receiver_Type_Count
        FROM receivers r
        GROUP BY r.Type
        ORDER BY Receiver_Type_Count;
        """,

        "23. Receiver count by city": """
        SELECT  
            City AS Receiver_City,
            COUNT(*) AS Receiver_city_count
        FROM receivers
        GROUP BY City
        ORDER BY Receiver_city_count DESC
        """,

        "24. Providers with most expired food": """
        SELECT 
            p.Name AS Provider_Name,
            COUNT(f.Food_ID) AS Expired_food_count
        FROM foodlistings f
        JOIN providers p ON f.Provider_ID=p.Provider_ID
        WHERE f.Expiry_Date<CURDATE()
        GROUP BY p.Provider_ID, p.Name
        ORDER BY Expired_food_count DESC
        LIMIT 5;
        """
    }

    query_choice = st.selectbox("Select SQL Query", list(queries.keys()))

    if "Contact info" in query_choice:
        city_input = st.text_input("Enter City Name")
        if city_input:
            cursor.execute(queries[query_choice], (city_input,))
            df = pd.DataFrame(cursor.fetchall(), columns=["Name", "Contact"])
            st.dataframe(df)
    else:
        cursor.execute(queries[query_choice])
        rows = cursor.fetchall()
        if rows:
            columns = [desc[0] for desc in cursor.description]
            df = pd.DataFrame(rows, columns=columns)
            st.dataframe(df)
        else:
            st.write("No data found for the selected query.")

elif page == 'Writer Info':
    #st.title("Sadguru Kripa")
    st.title("🧑‍💻 Developer Information")
    st.markdown("""
    ### 📌 Project Creator  
    **Name:** Ananya R  
    **Project:** Local Food Waste Management System  
    **Role:** Design & Development  
    """)
    
    st.markdown("""
    ### 🔗 Connect  
    - [LinkedIn Profile](https://www.linkedin.com/in/ananyar-80595a269/)
    """)
    st.markdown("---")

    st.markdown("""
    _"This project was built with the aim of optimizing modern data-driven techniques to facilitate quick and efficient management of real-world problems around food waste management."_  
    — *Ananya R*
    """)



else:
    print("Incorrect value error")
# Out:
# Overwriting food.py

# %%
! streamlit run food.py
# Out:
# ^C

# %%
st.form()

# %% [markdown]
# #Sadgurucharanaravindarpanamastu
